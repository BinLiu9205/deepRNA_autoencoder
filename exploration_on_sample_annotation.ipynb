# %% [markdown]
# # Exploration on the annotation to set up the samples of interest for downstream analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# %%
df = pd.read_csv('/mnt/dzl_bioinf/binliu/EMBL_ExpressionArray/arrayExpress_annotation.csv', sep='\t')

# %%
df.columns
# Out:
# Index(['Source Name', 'Material Type', 'Characteristics[organism]',
#        'Characteristics[cell type]', 'Characteristics[cell line]',
#        'Characteristics[tissue supergroup]', 'Characteristics[organism part]',
#        'Characteristics[metastatic tissue]', 'Characteristics[disease]',
#        'Characteristics[clinical history]', 'Characteristics[compound]',
#        'Characteristics[growth condition]', 'Characteristics[stimulus]',
#        'Characteristics[genotype]', 'Characteristics[RNAi]',
#        'Characteristics[phenotype]', 'Labeled Extract Name', 'Label',
#        'Assay Name', 'Technology Type', 'Comment [ArrayExpress accession]',
#        'Derived Array Data File', 'Comment [Derived ArrayExpress FTP file]',
#        'Factor Value[disease]', 'Factor Value[cell type]',
#        'Factor Value[cell line]', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29'],
#       dtype='object')

# %%
df.head(3)
# Out:
#   Source Name Material Type Characteristics[organism]  \
# 0    Sample 1          cell              Homo sapiens
# 1    Sample 2          cell              Homo sapiens
# 2    Sample 3          cell              Homo sapiens
#
#   Characteristics[cell type] Characteristics[cell line]  \
# 0      lung cancer cell line                 RERF-LC-KJ
# 1   ovarian cancer cell line                    FU-OV-1
# 2   colonic cancer cell line                   COLO-205
#
#   Characteristics[tissue supergroup] Characteristics[organism part]  \
# 0                               lung                           lung
# 1                              ovary                          ovary
# 2                         colorectal                          colon
#
#   Characteristics[metastatic tissue] Characteristics[disease]  \
# 0                     not applicable              lung cancer
# 1                     not applicable          ovary carcinoma
# 2                            ascites     colon adenocarcinoma
#
#   Characteristics[clinical history]  ... Comment [ArrayExpress accession]  \
# 0                                    ...                     E-GEOD-10843
# 1                                    ...                     E-GEOD-10843
# 2                                    ...                     E-GEOD-10843
#
#                Derived Array Data File  \
# 0  processedMatrix.Aurora.july2015.txt
# 1  processedMatrix.Aurora.july2015.txt
# 2  processedMatrix.Aurora.july2015.txt
#
#              Comment [Derived ArrayExpress FTP file] Factor Value[disease]  \
# 0  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...           lung cancer
# 1  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...       ovary carcinoma
# 2  ftp://ftp.ebi.ac.uk/pub/databases/microarray/d...  colon adenocarcinoma
#
#     Factor Value[cell type] Factor Value[cell line] Unnamed: 26 Unnamed: 27  \
# 0     lung cancer cell line              RERF-LC-KJ         NaN         NaN
# 1  ovarian cancer cell line                 FU-OV-1         NaN         NaN
# 2  colonic cancer cell line                COLO-205         NaN         NaN
#
#   Unnamed: 28 Unnamed: 29
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
#
# [3 rows x 30 columns]

# %% [markdown]
# ## Sorting the organ and tissue information

# %%
cell_type_sorted = Counter(df['Characteristics[cell type]']).most_common()
cell_type_sorted
# Out:
# [('  ', 13104),
#  ('mononuclear cell', 1507),
#  ('breast cancer cell line', 673),
#  ('epithelial cell', 435),
#  ('breast tumor cell', 401),
#  ('lymphoblastoid cell line', 395),
#  ('hepatocellular carcinoma cell line', 355),
#  ('EBV-transformed lymphoblastoid cell line', 348),
#  ('airway epithelial cell', 300),
#  ('blasts and mononuclear cells', 297),
#  ('cervical carcinoma cell line', 247),
#  ('leukocyte', 236),
#  ('huvec', 223),
#  ('B-cell derived cell line', 218),
#  ('lung adenocarcinoma cell line', 208),
#  ('CD138-selected cells', 201),
#  ('neuroblastoma cell line', 194),
#  ('colorectal cancer cell line', 190),
#  ('fibroblast', 187),
#  ('CD138+ plasma cell', 182),
#  ('embryonic kidney derived cell line', 173),
#  ('endometrial adenocarcinoma cell line', 168),
#  ('monocyte', 155),
#  ('mesenchymal stem cell', 147),
#  ('monocyte-derived dendritic cell', 134),
#  ('macrophage', 133),
#  ('lymphocyte', 115),
#  ('T-ALL cell', 114),
#  ('CD138-purified plasma cells', 114),
#  ('smooth muscle cell', 101),
#  ('dendritic cell', 95),
#  ('white blood cell', 94),
#  ('colorectal adenocarcinoma cell line', 92),
#  ('pancreatic cancer cell line', 90),
#  ('human embryonic stem cell line', 89),
#  ('mammary epithelial cell line', 88),
#  ('melanoma cell line', 86),
#  ('polymorphonuclear leukocyte', 85),
#  ('prostate adenocarcinoma cell line', 85),
#  ('lung cancer cell line', 83),
#  ('acute monocytic leukaemia cell line', 82),
#  ('endothelial cell', 78),
#  ('osteosarcoma cell line', 78),
#  ('ovarian adenocarcinoma cell line', 76),
#  ('glioma cell line', 76),
#  ('colonic cancer cell line', 74),
#  ('bronchiole epithelial cell line', 74),
#  ('diffuse large B-cell lymphoma cell', 72),
#  ('neuroblastoma tumor cell', 71),
#  ('lymphoma cell', 70),
#  ('blast', 70),
#  ('metastatic melanoma cell line', 67),
#  ('diffuse histiocytic lymphoma cell line', 66),
#  ('myeloma cell line', 66),
#  ('promyelocyte', 63),
#  ('T-cell', 61),
#  ('leukemic lymphoblast', 61),
#  ('keratinocyte', 57),
#  ('non-small cell lung cancer cell line', 56),
#  ('prostate cancer cell line', 56),
#  ('melanoma derived cell line', 55),
#  ('prostatic cancer cell line', 55),
#  ('bronchial epithelial cell derived cell line', 54),
#  ('plasma cell', 54),
#  ('alveolar macrophage', 53),
#  ('adipose-derived stem cell', 53),
#  ('multiple myeloma cell line', 52),
#  ('glioblastoma cell line', 51),
#  ('T-cell leukaemia cell line', 51),
#  ('monocyte-derived macrophage', 51),
#  ('AML cell line', 50),
#  ('stromal cell', 50),
#  ('retinal pigment epithelial cell line', 49),
#  ('hepatocyte', 49),
#  ('gastric cancer cell line', 47),
#  ('hepatoma cell line', 45),
#  ('cd19+ tumor cell', 43),
#  ('ovarian cancer cell line', 42),
#  ('B-cell', 42),
#  ('lung fibroblast derived cell line', 42),
#  ('CD34+ cells', 41),
#  ('EBV-immortalized B-lymphoblastoid cell line', 41),
#  ('hematopoietic stem cell', 41),
#  ('scalp fibroblast', 40),
#  ('CD138 plasma cell', 40),
#  ('ALL cell line', 39),
#  ('myometrial cell', 39),
#  ('lymphoblast cell line', 38),
#  ('fibrosarcoma derived cell line', 37),
#  ('osteoblast', 36),
#  ('fibroblast derived cell line', 36),
#  ('CD138+ selected plasma cells', 35),
#  ('CD34+ cell', 35),
#  ('CML cell line', 34),
#  ('brain cancer cell line', 34),
#  ('CD3+ T-cell', 33),
#  ('islet beta cell', 32),
#  ('skin fibroblast cell line', 32),
#  ('neutrophil', 32),
#  ('CD8+ T-cell', 32),
#  ('NK cell', 31),
#  ('adult T-cell leukaemia cell line', 31),
#  ('lymphatic endothelial cell', 31),
#  ('induced pluripotent stem cell line', 31),
#  ('chondrocyte', 30),
#  ('CD4+ T-cell', 29),
#  ('Burkitt lymphoma cell line', 27),
#  ('epithelium', 27),
#  ('hESC', 27),
#  ('renal cancer cell line', 27),
#  ('non-small cell lung carcinoma cell line', 26),
#  ('neuroblastic tumor cell', 26),
#  ('chronic lymphocytic leukemia cell', 26),
#  ('squamous cell carcinoma cell line', 26),
#  ('CD14+ monocyte', 25),
#  ('adrenocortical carcinoma cell line', 25),
#  ('precursor B-cell', 24),
#  ('granulosa cell', 24),
#  ('renal proximal tubular cell line', 24),
#  ('B-cell lymphoma cell line', 24),
#  ('T-cell lymphoma cell line', 24),
#  ('prostate epithelial cell line', 23),
#  ('small cell lung cancer cell line', 21),
#  ('non-Hodgkins lymphoma cell line', 21),
#  ('intestinal mucosa', 21),
#  ('EBV-immortalized B-cell line', 21),
#  ('lymphoma cell line', 21),
#  ('neonatal foreskin-derived', 20),
#  ('skin fibroblast derived cell line', 20),
#  ('lymphoblast', 19),
#  ('immature dendritic cell', 19),
#  ('microvascular endothelial cell', 18),
#  ('fetal retinal pigment epithelium', 18),
#  ('CD36+ erythroid progenitor cell', 18),
#  ('oocyte', 18),
#  ('fibroblast cell line', 18),
#  ('dermal fibroblast', 18),
#  ('alveolar leukocyte', 18),
#  ('T-cell line', 17),
#  ('metastatic lung cancer in brain', 17),
#  ('cutaneous T-cell lymphoma cell line', 17),
#  ('CD34 positive mononuclear', 17),
#  ('testicular diffuse large B-cell lymphoma tissue', 16),
#  ('leukaemia cell line', 16),
#  ('nodal diffuse large B-cell lymphoma cell', 15),
#  ('esophageal adenocarcinoma cell line', 15),
#  ('metastatic clear-cell renal cell carcinoma in lung', 15),
#  ('dermal microvascular endothelial cell line', 15),
#  ('glioblastoma derived neurosphere culture cell line', 15),
#  ('pharyngeal carcinoma cell line', 15),
#  ('human embryonic kidney cell', 15),
#  ('esophageal squamous epithelium cell line', 15),
#  ('metastatic breast cancer in brain', 14),
#  ('medulloblastoma cell line', 14),
#  ('mesenchymal progenitor cell line', 14),
#  ('iPSC', 14),
#  ('amnion cell line', 13),
#  ("Barrett's syndrome cell line", 13),
#  ('CD19+ B-cell', 13),
#  ('regulatory T-cell', 12),
#  ('metastatic colorectal cancer in liver', 12),
#  ('marrow stromal cell', 12),
#  ('immortalised T lymphocyte cell line', 12),
#  ('TCRVgamma9+ gamma delta T cells', 12),
#  ('amniocyte', 12),
#  ('prenatal chorion villus cell', 12),
#  ('B-lymphocyte', 12),
#  ('plasmacytoid dendritic cell', 12),
#  ('CD19+ cell', 12),
#  ('CD34-derived erythroid progenitors', 12),
#  ('ovarian serous carcinoma cell line', 12),
#  ('blood vessel endothelial cell', 12),
#  ('immortalized bronchial epithelial cell', 12),
#  ('liver mesenchymal tumor cell line', 12),
#  ('intestine epithelial cell', 12),
#  ('cell line mixture', 12),
#  ('testicular germ-cell tumor cell line', 12),
#  ('epidermal keratinocyte cell line', 12),
#  ('umbilical cord blood derived mesenchymal stem cell', 12),
#  ('CD4 T-cell', 11),
#  ('CD8 T-cell', 11),
#  ('myeloid monocytic cell', 11),
#  ('universal human reference RNA', 11),
#  ('tumorigenic', 11),
#  ('prostate cancer stem cell line', 11),
#  ('CLL cell line', 10),
#  ('umbilical cord blood derived endothelial colony', 10),
#  ('glioblastoma stem-like cell line', 10),
#  ('embryonal carcinoma cell line', 10),
#  ('gamma-delta T-cell', 10),
#  ('CD133-/alpha2 integrin low prostate epithelial cells', 10),
#  ('BJ-derived hIPS', 10),
#  ('EBV+ T-cell line', 10),
#  ('non-small cell lung adenocarcinoma cell line', 10),
#  ('extranodal NK/T-cell lymphoma cell', 10),
#  ('gastric adenocarcinoma cell lines', 10),
#  ('CD8 positive T-cell', 10),
#  ('bone sarcoma cell line', 9),
#  ('clear cell renal carcinoma cell line', 9),
#  ('endometrial cancer cell line', 9),
#  ('lymphocytic leukaemia cell line', 9),
#  ('epidermoid carcinoma cell line', 9),
#  ('CD4 positive T-cell', 9),
#  ('urothelial', 9),
#  ('rhabdomyosarcoma cell line', 9),
#  ('mammary epithelial cell derived cell line', 9),
#  ('geminal center centroblast', 8),
#  ('mesenchymal stem cell-derived adipocyte', 8),
#  ('mesenchymal stem cell-derived stromal', 8),
#  ('immortalized ovarian surface epithelial cell line', 8),
#  ('mantle cell lymphoma cell line', 8),
#  ('fetal lung fibroblast derived cell line', 8),
#  ('iPSC derived from fibroblast', 8),
#  ('trophoblast cell line', 8),
#  ("non-Hodgkin's lymphoma cell line", 8),
#  ('mesenchymal stem cell-derived stromal and adipocyte', 8),
#  ('urothelial cell line', 8),
#  ('prostate epithelial cell', 8),
#  ('vascular smooth muscle cell', 8),
#  ('ovarian carcinoma cell line', 8),
#  ('vascular endothelial cell', 8),
#  ('immortalized B-cell', 7),
#  ('Hodgkins lymphoma B-cell line', 7),
#  ('metastatic breast cancer in bone', 7),
#  ('human umbilical vein endothelial cell line', 7),
#  ('B-lymphoblastoid cell line', 7),
#  ('CD34+ progenitor cell', 7),
#  ('mesenchymal stem cell clone', 7),
#  ('malignant peripheral nerve sheath tumor cell line', 7),
#  ('large vessel endothelial cell derived from embryoid body', 7),
#  ('nasopharyngeal carcinoma cell line', 7),
#  ('cell line derived from HT1080 ', 7),
#  ('gastric adenocarcinoma cell line', 7),
#  ('esophageal squamous cell', 6),
#  ('colon fibroblast derived cell line', 6),
#  ('AIDS-NHL-derived cell line', 6),
#  ('iPSC derived from human adipose stem cells', 6),
#  ('head and neck cancer cell line', 6),
#  ('mammary fibroblast derived cell line', 6),
#  ('immortalized bronchial epithelial cell line', 6),
#  ('dendritic cell derived from mature monocyte', 6),
#  ('breast cell line', 6),
#  ('dental pulp stem cell', 6),
#  ('memory B-cell', 6),
#  ('prostate stromal cell', 6),
#  ('rhabdomyosarcoma cell', 6),
#  ('breast tumor cell line', 6),
#  ('hTERT-immortalized human mammary epithelial cell line', 6),
#  ('transformed lymphocyte', 6),
#  ('tracheal epithelial cell line', 6),
#  ('lung squamous cell carcinoma cell line', 6),
#  ('dermal microvascular lymphatic endothelial cell', 6),
#  ('primitive neural epithelial cell from embryonic stem cell line H9', 6),
#  ('ascites cell', 6),
#  ('iPSC derived from cell line CCD-1079Sk', 6),
#  ('proximal tubular epithelial cell', 6),
#  ('in vitro generated osteoclasts', 6),
#  ('Ewing family tumor cell line', 6),
#  ('CD14 positive mononuclear cell', 6),
#  ('renal proximal tubular epithelial cell', 6),
#  ('bronchioalveolar carcinoma cell line', 6),
#  ('germinal center B-cell', 5),
#  ('HLA-DR negative T-cell', 5),
#  ('T-ALL cell line', 5),
#  ('epithelial cell line', 5),
#  ('primary T lymphocyte', 5),
#  ('neural crest cell line', 5),
#  ('Hodgkins lymphoma cell line', 5),
#  ('glioblastoma derived cell line', 5),
#  ('B-lymphocyte cell line', 5),
#  ('natural killer cell line', 5),
#  ('intestinal epithelial cell line', 5),
#  ('iPSC derived from fibroblast cell line dH1F', 5),
#  ('iPSC derived from fibroblast cell line BJ', 5),
#  ('pulmonary microvascular endothelial cell', 5),
#  ('CD133+ prostate epithelial cells', 5),
#  ('fetal cortex derived cell line', 5),
#  ('hTERT-immortalized breast primary epithelial cell line', 5),
#  ('naive T-cell', 5),
#  ('central memory T-cell', 5),
#  ('fibroblast-like synovial cell', 5),
#  ('esophagus', 5),
#  ('HLA-DR+ T-cell', 5),
#  ('erythroleukaemia cell line', 5),
#  ('neural epithelial cell from embryonic stem cell line H9', 5),
#  ('cloned fibroblast cell line', 4),
#  ('nasopharingeal carcinoma cell line', 4),
#  ('CD14+ CD16- monocyte', 4),
#  ('fetal gamma-delta T-cell', 4),
#  ('breast epithelial cell derived cell line', 4),
#  ('hepatic stellate', 4),
#  ('mesendoderm/endoderm progenitor cell', 4),
#  ('CD8+ central memory T cell', 4),
#  ('myelodysplasia cell line', 4),
#  ('centrocyte', 4),
#  ('CD21lo transitional B cell', 4),
#  ('retinal pigment epithelial cell', 4),
#  ('esophageal epithelial cell', 4),
#  ('hypopharyngeal tumor cell line', 4),
#  ('embryoid body derived from cell line H9', 4),
#  (' T-cell line', 4),
#  ('effector memory T-cell', 4),
#  ('centroblast', 4),
#  ('colon cancer stem cell', 4),
#  ('CD8+ effector memory RA T cell', 4),
#  ('chondrogenic progenitor cells', 4),
#  ('fibroblast differentiated from H1', 4),
#  ('glomerular podocyte', 4),
#  ('iPSC derived from fibroblast cell line dH1CF', 4),
#  ('BDCA3+ dendritic cell', 4),
#  ('CD3 cells', 4),
#  ('liposarcoma cell line', 4),
#  ('fetal fibroblast', 4),
#  ('CD8+ naive CD8 T cell', 4),
#  ('odontoblast', 4),
#  ('CD8+ effector memory T cell', 3),
#  ('myoepithelial', 3),
#  ('mesothelioma cell line', 3),
#  ('iPSC from bone marrow mononuclear cell', 3),
#  ('oral keratinocyte', 3),
#  ('CD8+CD28- T-cell', 3),
#  ('activated B-cell', 3),
#  ('CD16+ dendritic', 3),
#  ('CD14 cells', 3),
#  ('CD14-positive monocyte', 3),
#  ('mesothelium cell line', 3),
#  ('mesodermal precursor cell derived from hES cells line VUB01', 3),
#  ('mesenchymal stem cell from iliac crest', 3),
#  ('ileum mucosa', 3),
#  ('CD14low CD16+ monocyte', 3),
#  ('CD16- monocyte', 3),
#  ('CD15 cells', 3),
#  ('ileocecal carcinoma cell line', 3),
#  ('Norwalk virus replicon-bearing hepatoma cell line', 3),
#  ('lymphoid cell', 3),
#  ('CD16 negative mononuclear cell', 3),
#  ('retinal pigment epithelium', 3),
#  ('alveolar epithelial progenitor cell', 3),
#  ('head and neck squamous cell carcinoma cell line', 3),
#  ('CD41 negative portion', 3),
#  ('chondrosarcoma cell line', 3),
#  ('mesodermal precursor cell derived from hES cells line SA01', 3),
#  ('human embryonic stem cell line (post hepatic differentiation)', 3),
#  ('CD21hi transitional B cell', 3),
#  ('BDCA1+ dendritic cell', 3),
#  ('luminal epithelial cell', 3),
#  ('CD1c+ dendritic cell', 3),
#  ('CD4CD45RO T-cell', 3),
#  ('neural progenitor cell line', 3),
#  ('metastatic midgut carcinoid in liver', 3),
#  ('immature monocyte-derived dendritic cell', 3),
#  ('small cell lung carcinoma cell line', 3),
#  ('midgut carcinoid', 3),
#  ('CD16+ monocyte', 3),
#  ('CD16 positive mononuclear cell', 2),
#  ('aortic vascular smooth muscle cell', 2),
#  ('atypical ductal hyperplasia cell line', 2),
#  ('periodontal ligament cell', 2),
#  ('cell line derived from primary cancer associated fibroblasts', 2),
#  ('NSCLC cell line', 2),
#  ('eosinophilic cell line', 2),
#  ('skin fibroblast', 2),
#  ('esophageal carcinoma cell line', 2),
#  ('alveolar cell carcinoma cell line', 2),
#  ('human umbilical cord lining epithelial cell', 2),
#  ('oligoastrocytoma derived cell line', 2),
#  ('CD4 T cell line', 2),
#  ('human vascular adventitial fibroblast', 2),
#  ('iPSC derived from fibroblast cell line IMR90', 2),
#  ('intermediate cell derived from dendritic cells', 2),
#  ('metastatic prostate cancer cell line', 2),
#  ('EBV+ lymphoblastoid cell line', 2),
#  ('placenta choriocarcinoma cell line', 2),
#  ('primary fibroblast culture', 2),
#  ('undifferentiated induced pluripotent stem cell', 2),
#  ('non-small cell carcinoma cell line', 2),
#  ('CD41+ cord blood derived megakaryocytes', 2),
#  ('osteoclast derived from dendritic cells', 2),
#  ('bone marrow stromal cell line', 2),
#  ('ATL-derived cell line', 2),
#  ('unrestricted somatic stem cell', 2),
#  ('Pre-B leukaemia cell line', 2),
#  ('hematopoietic cell', 2),
#  ('CD34+ haematopoietic stem cell', 2),
#  ('naive B-cell', 2),
#  ('lung tissue-derived fibroblast', 2),
#  ('foreskin-derived iPSC', 2),
#  ('erythrocyte', 2),
#  ('megakaryoblast', 2),
#  ('CD34-negative', 2),
#  ('lipoma derived mesenchymal stem cell', 2),
#  ('naive B cell', 2),
#  ('T-cell and retinal pigment epithelial cell (co-cultured)', 2),
#  ('CD8+CD28+ T-cell', 2),
#  ('primary hematopoietic CD34+ cells', 2),
#  ('mixed somatic cell types', 2),
#  ('pancreatic adenocarcinoma cell line', 2),
#  ('malignant mesothelioma cell line', 2),
#  ('cell line derived from primary pancreatic ductal adenocarcinoma', 2),
#  ('mesodermal precursor cell derived from hES cells line VUB03_DM1', 2),
#  ('embryoid body derived from cell line hES-T3', 2),
#  ('granulopoietic cell', 2),
#  ('tarsal conjuntiva', 2),
#  ('CD8+ cell', 2),
#  ('CD34+ hematopoietic progenitor cell', 2),
#  ('EBV+ natural killer cell line', 2),
#  ('colonic epithelial cancer cell line', 2),
#  ('AMKL cell line', 2),
#  ('megakaryoblastic leukaemia cell line', 2),
#  ('osteoclast derived from monocytes', 2),
#  ('endometrial cell', 2),
#  ('pituitary adenoma cell line', 2),
#  ('coronary endothelial cell', 2),
#  ('hESC-derived endothelial cell', 2),
#  ('CD4+ cell', 2),
#  ('multipotent stromal cell', 2),
#  ('plasmablast', 2),
#  ('pancreatic islet-like cell clusters derived from cell line T3ES', 2),
#  ('neural progenitor cell from developing cortex', 2),
#  ('intermediate cell derived from monocytes', 2),
#  ('gingival keratinocyte cell line', 1),
#  ('virus-transformed lung/bronchus epithelial cell line', 1),
#  ('CD133-/aplha2 integrin low prostate epithelial cells', 1),
#  ('plasma B-cell', 1),
#  ('immunoblastic large cell lymphoma cell line', 1),
#  ('pharyngeal tumor cell line', 1),
#  ('iPSC derived from fibroblast cell line MRC-6', 1),
#  ('monocyte/macrophage', 1),
#  ('Langerhans cell', 1),
#  ('colonic epithelial cell', 1),
#  ('iPSC derived from fibroblast cell line MRC-5', 1),
#  ('CD34+CD19+ pro-B-cell', 1),
#  ('melanocyte', 1),
#  ('mammary epithelial cell', 1),
#  ('fibroblast-derived iPSC', 1),
#  ('dermal dendritic cell', 1),
#  ('diffuse mixed lymphoma cell line', 1),
#  ('neural progenitor cells', 1),
#  ('lymphoma', 1),
#  ('fibroblast cell lines pool', 1),
#  ('malignant peripheral nerve sheath cell line', 1),
#  ('metamyelocyte/granulocyte', 1),
#  ('blast/promyelocyte', 1),
#  ('blast/promonocyte', 1),
#  ('endothelial precursor cell derived from human umbilical cord blood', 1),
#  ('DS-AMKL cell line', 1),
#  ('foreskin fibroblast derived cell line', 1),
#  ('esophageal squamous carcinoma cell line', 1),
#  ('intestinal adenocarcinoma cell line', 1),
#  ('EBV-transformed B-cell line', 1),
#  ('astrocyte  derived from cell line H9', 1),
#  ('myoepithelial cells differentiated from hTERT-immortalized K5+K19- mammary epithelial cell',
#   1),
#  ('neural progenitor cell from ventral midbrain', 1),
#  ('choroid', 1),
#  ('fetal osteoblast derived cell line', 1),
#  ('blast/proerythroblast', 1),
#  ('skin derived fibroblast cell line', 1),
#  ('fibroblastic cell line', 1),
#  ('EBV-transformed natural killer cell line', 1),
#  ('iPSC from CML bone marrow mononuclear cell', 1),
#  ('epidermal melanocyte', 1),
#  ('bone marrow derived cell line', 1),
#  ('stem cell line', 1),
#  ('human umbilical vein smooth muscle cell', 1),
#  ('metastatic pancreatic cancer cell line', 1),
#  ('blast derived from cell line H9', 1),
#  ('iPSC derived from fibroblast cell line MRC-9', 1),
#  ('glioblastoma-derived stem cell', 1),
#  ('metastatic breast cancer in lung', 1),
#  ('mesenchymal stromal cell', 1),
#  ('NK/T-cell lymphoma cell line', 1),
#  ('naive CD4+ T-cell', 1),
#  ('iPSC derived from fibroblast cell line MRC-8', 1),
#  ('forelimb leiomyosarcoma cell line', 1),
#  ('hematopoietic stem cell/progenitor cell', 1),
#  ('cumulus cell', 1),
#  ('giant cell glioblatoma derived cell line', 1),
#  ('mammospheres derived from breast tumor', 1),
#  ('lymphoid RNA reference', 1),
#  ('gingival fibroblast', 1),
#  ('diffuse large cell lymphoma cell line', 1),
#  ('CD3-positive T cell', 1),
#  ('myeloid cell', 1),
#  ('iPSC cell line from cord blood mononuclear cell', 1),
#  ('human embryonic carcinoma cell', 1),
#  ('skin melanoma cell line', 1),
#  ('erythroblast', 1),
#  ('embryonic kidney cell line', 1),
#  ('myelocyte/metamyelocyte', 1),
#  ('prostate carcinoma cell line', 1),
#  ('pancreatic carcinoma cell line', 1),
#  ('endothelial cell differentiated from human umbilical cord blood derived-EPCs',
#   1),
#  ('cancer cell lines', 1),
#  ('natural killer leukaemia cell line', 1),
#  ('iPSC derived from fibroblast cell line MRC-7', 1),
#  ('megakaryocyte', 1)]

# %%
disease_status_sorted = Counter(df['Characteristics[disease]']).most_common()
disease_status_sorted
# Out:
# [('normal', 9423),
#  ('acute myeloid leukaemia', 974),
#  ('chronic lymphocytic leukaemia', 757),
#  ('breast cancer', 717),
#  ('breast adenocarcinoma', 567),
#  ('multiple myeloma', 532),
#  ('diffuse large B-cell lymphoma', 460),
#  ('colorectal adenocarcinoma', 366),
#  ('hepatocellular carcinoma', 362),
#  ('ovarian carcinoma', 331),
#  ('melanoma', 320),
#  ('neuroblastoma', 282),
#  ('lung adenocarcinoma', 273),
#  ('gastric cancer', 260),
#  ('Pre-B-ALL/c-ALL', 253),
#  ('cervical adenocarcinoma', 238),
#  ('multiple sclerosis or clinically isolated syndrome', 237),
#  ('asthma', 234),
#  ('T-ALL', 230),
#  ('periodontitis', 226),
#  ('NSCLC', 219),
#  ('glioblastoma', 214),
#  ('myeloma', 208),
#  ('obesity', 205),
#  ('no rejection', 203),
#  ('myelodysplastic syndrome', 190),
#  ('acute myeloid leukaemia ', 181),
#  ('colon carcinoma', 179),
#  ('endometrial adenocarcinoma', 168),
#  ('ALL', 163),
#  ('septic shock', 163),
#  ('pancreatic cancer', 152),
#  ('AML/other abnormalities', 140),
#  ('lung cancer', 136),
#  ('undifferentiated sarcoma', 129),
#  ('osteosarcoma', 116),
#  ('carcinoma', 116),
#  ('primary breast tumor', 116),
#  ('invasive ductal carcinoma', 114),
#  ('prostate adenocarcinoma', 108),
#  ('chronic myeloid leukaemia', 105),
#  ('acute monocytic leukaemia', 103),
#  ("Crohn's disease", 100),
#  ('ovarian adenocarcinoma', 89),
#  ('peripheral T-cell lymphoma', 87),
#  ('ulcerative colitis', 84),
#  ('colon adenocarcinoma', 82),
#  ('kidney transplant recipient', 82),
#  ('sepsis', 78),
#  ('leiomyoma', 76),
#  ('irritable bowel syndrome', 76),
#  ('breast fibrocystic disease', 74),
#  ('burn', 74),
#  ('leiomyosarcoma', 74),
#  ('allograft rejection', 74),
#  ('pediatric T-ALL', 73),
#  ('meningioma', 72),
#  ('prostate cancer', 69),
#  ('precursor B-cell acute lymphoblastic leukaemia', 69),
#  ('prostate carcinoma', 68),
#  ('HCV/hepatocellular carcinoma', 66),
#  ('psoriasis', 63),
#  ('childhood B-cell precursor ALL', 63),
#  ('gastrointestinal stromal tumor', 61),
#  ('colorectal cancer', 57),
#  ('ovarian cancer', 57),
#  ('ductal carcinoma', 56),
#  ('benign prostatic hyperplasia', 56),
#  ('hepatitis C virus-induced hepatocellular carcinoma', 55),
#  ('diffuse histiocytic lymphoma', 54),
#  ('schizophrenia', 54),
#  ('liposarcoma', 53),
#  ('colorectal carcinoma', 52),
#  ('T-cell leukaemia', 51),
#  ('ependymoma', 50),
#  ('acute graft-versus-host disease', 49),
#  ('breast ductal adenocarcinoma', 48),
#  ('COPD', 47),
#  ('acute lymphoblastic leukaemia', 47),
#  ('B-ALL', 46),
#  ('glioma', 46),
#  ('high-grade prostatic intraepithelial neoplasia', 45),
#  ('adenocarcinoma', 44),
#  ('B-cell lymphoma', 43),
#  ('osteoarthritis', 41),
#  ('endometriosis', 40),
#  ('erythroleukaemia', 39),
#  ('hepatoma', 39),
#  ('systemic inflammatory response syndrome', 38),
#  ('Pro-B-ALL/MLL', 37),
#  ('lung fibrosarcoma', 37),
#  ('rheumatoid arthritis', 37),
#  ('pilocytic astrocytoma', 37),
#  ('cervical cancer', 37),
#  ('pediatric acute leukaemia', 37),
#  ('juvenile myelomonocytic leukaemia', 36),
#  ('AML(FAB-M0)', 34),
#  ("Job's syndrome", 34),
#  ('ALL without MLL rearrangement', 33),
#  ('non-Hodgkins lymphoma', 33),
#  ('neuroblastoma (Ewing sarcoma)', 33),
#  ('c-ALL', 33),
#  ('moderately differentiated head and neck squamous cell carcinoma', 33),
#  ("Ewing's sarcoma", 33),
#  ('breast ductal carcinoma', 32),
#  ('pulmonary MALT lymphoma', 32),
#  ('prolapse', 31),
#  ('clinically isolated syndrome', 31),
#  ('Kawasaki disease', 31),
#  ('common ALL', 31),
#  ('ATL', 30),
#  ('ovarian serous carcinoma', 30),
#  ('cutaneous T-cell lymphoma', 30),
#  ('diffuse glioma', 30),
#  ('colorectal adenoma', 30),
#  ("chronic Hodgkin's lymphoma", 30),
#  ('non-small cell lung cancer', 30),
#  ('dilated cardiomyopathy', 29),
#  ('meningococcal sepsis', 29),
#  ('nasopharyngeal carcinoma', 29),
#  ('AML/MLL', 29),
#  ('biliary atresia', 28),
#  ('breast carcinoma', 28),
#  ('basal-like breast cancer', 28),
#  ('medulloblastoma', 28),
#  ('moderate chronic allograft nephropathy', 27),
#  ('acute promyelocytic leukaemia', 27),
#  ('  ', 27),
#  ('autism spectrum disorder', 27),
#  ('primary unilateral non-metastatic breast cancer', 26),
#  ('familial hypercholesterolemia', 26),
#  ('adrenocortical carcinoma', 26),
#  ('Burkitt lymphoma', 25),
#  ('pre-diabetes', 25),
#  ('lymphoma', 25),
#  ('malignant melanoma', 25),
#  ('clear-cell renal cell carcinoma', 24),
#  ('multiple sclerosis', 24),
#  ('Sjogren syndrome', 24),
#  ('gastric adenocarcinoma', 24),
#  ('serous epithelial ovarian cancer', 23),
#  ('adenoma', 23),
#  ('glioblastoma multiforme', 23),
#  ('AML/aberrant karyotype', 23),
#  ('mild chronic allograft nephropathy', 22),
#  ('juvenile idiopathic arthritis', 22),
#  ('mantle cell lymphoma', 22),
#  ('celiac', 22),
#  ('oligoarticular juvenile idiopathic arthritis', 21),
#  ('neuroepithelioma', 21),
#  ('renal cell carcinoma', 21),
#  ('renal cancer', 21),
#  ('recessive retinitis pigmentosa', 21),
#  ('squamous cell carcinoma', 21),
#  ('non-basal like breast cancer', 21),
#  ('IFTA', 21),
#  ('severe chronic allograft nephropathy', 21),
#  ('ALL/hyperdiploid karyotype', 20),
#  ('small cell lung cancer', 20),
#  ('head and neck cancer', 20),
#  ('lobular carcinoma', 20),
#  ('uterine fibroid', 20),
#  ('HIV-1', 20),
#  ('infiltrating ductal carcinoma', 20),
#  ('sarcoma', 19),
#  ('chromophobe renal cell carcinoma', 18),
#  ('rectal adenocarcinoma', 18),
#  ('polycystic ovary syndrome', 18),
#  ('nickel allergy', 18),
#  ('testicular diffuse large B-cell lymphoma', 17),
#  ('vessel ischemic heart disease', 17),
#  ('chronic fatigue', 17),
#  ('AML without MLL rearrangement', 17),
#  ('follicular carcinoma', 17),
#  ('breast carcinoma/cystic change', 17),
#  ('CNS affected', 16),
#  ('type 2 diabetes mellitus', 16),
#  ('follicular adenoma', 16),
#  ('poorly differentiated head and neck squamous cell carcinoma', 16),
#  ('Cornelia de Lange Syndrome', 16),
#  ('lung carcinoma', 16),
#  ('Thompson disease', 16),
#  ('ejaculatory azoospermia/idiopathic infertility', 16),
#  ('ischemic cardiomyopathy', 15),
#  ('nodal diffuse large B-cell lymphoma', 15),
#  ('ankylosing spondylitis', 15),
#  ('mycosis fungoide (cutaneus T-cell lymphoma)', 15),
#  ('esophageal adenocarcinoma', 15),
#  ('CCRCC', 15),
#  ('hypertriglyceridemia', 15),
#  ('basal cell carcinoma', 15),
#  ("Parkinson's disease", 15),
#  ('pharyngeal carcinoma', 15),
#  ('tongue squamous cell carcinoma', 15),
#  ('rhabdomyosarcoma', 15),
#  ('myelodysplastic syndrome/refractory anemia with excess blasts', 15),
#  ('soft tissue sarcoma', 15),
#  ('erosive gastritis', 15),
#  ('renal disease', 14),
#  ('alveolar soft-part sarcoma', 14),
#  ('conventional mantle cell lymphoma', 14),
#  ('pediatric-high grade glioma/glioblastoma', 14),
#  ('nodal peripheral T-cell lymphoma', 14),
#  ('desmoplastic cerebellar medulloblastoma', 14),
#  ('unilateral cryptorchid', 14),
#  ('colon adenoma', 14),
#  ('fibrocystic disease', 14),
#  ('pancreatic adenocarcinoma', 14),
#  ('interstitial cystitis', 14),
#  ('diarrhea-irritable bowel syndrome', 14),
#  ('HeLa cell contamination', 13),
#  ('recurrent glioblastoma', 13),
#  ('polyarticular juvenile idiopathic arthritis', 13),
#  ('well differentiated head and neck squamous cell carcinoma', 13),
#  ('lung anaplastic carcinoma', 13),
#  ('systemic inflammatory response syndrome resolved', 13),
#  ("Barret's syndrome", 13),
#  ('oral cavity squamous cell carcinoma', 13),
#  ('angioimmunoblastic T-cell lymphoma', 13),
#  ('inflammatory bowel disease', 13),
#  ('subclinical interstitial fibrosis', 13),
#  ('leukaemia', 13),
#  ('colon cancer', 12),
#  ('Hodgkins lymphoma', 12),
#  ('septic patient', 12),
#  ('angina/coronary atherosclerosis', 12),
#  ('bronchopulmonary dysplasia', 12),
#  ('acyanotic Tetralogy of Fallot', 12),
#  ('epilepsy', 12),
#  ('liver mesenchymal tumor', 12),
#  ('undifferentiated soft tissue sarcoma', 12),
#  ('MALT lymphoma', 12),
#  ("Pick's disease", 12),
#  ('mixture', 12),
#  ('hip arthroplasty', 12),
#  ('absense epilepsy', 12),
#  ('HCV', 12),
#  ('fetal adenoma', 12),
#  ('epidermoid carcinoma', 11),
#  ('hyperplastic polyp', 11),
#  ('her2+ breast cancer', 11),
#  ('unknown', 11),
#  ('type 2 diabetes', 11),
#  ('renal oncocytoma', 11),
#  ('papillary thyroid cancer', 11),
#  ('not applicable', 11),
#  ('larynx squamous cell carcinoma', 11),
#  ('primary glioblastoma', 11),
#  ('differentiated liposarcoma', 11),
#  ('adrenocortical tumor', 11),
#  ('myelodysplastic syndrome/refractory anemia with ringed sideroblasts', 11),
#  ('pre B-ALL', 11),
#  ('renal adenocarcinoma', 10),
#  ('endemic Burkitt lymphoma', 10),
#  ('high risk B-precurser ALL', 10),
#  ('malignant pluripotent embryonal carcinoma', 10),
#  ('T-cell/histiocyte rich B-cell lymphoma', 10),
#  ('Apert syndrome', 10),
#  ('Muenke syndrome', 10),
#  ("Alzheimer's disease", 10),
#  ('myelodysplastic syndrome/refractory anemia', 10),
#  ('scleroderma without pulmonary hypertension', 10),
#  ('scleroderma with pulmonary hypertension', 10),
#  ('AML with normal karyotype and other abnormalities', 10),
#  ("nodular lymphocyte predominant Hodgkin's lymphoma", 10),
#  ('thalassemia', 10),
#  ('AML with t 11q23', 10),
#  ('metastatic prostate cancer', 10),
#  ('nonsyndromic sagittal synostosis', 10),
#  ('extranodal NK/T-cell lymphoma', 10),
#  ('Soetre-Chotzen syndrome', 10),
#  ('monoclonal gammopathy of unknown significance', 10),
#  ('atopy', 10),
#  ('house dust mite allergy', 10),
#  ('Sezary syndrome', 9),
#  ('endometrial cancer', 9),
#  ('vulvar intraepithelial neoplasia', 9),
#  ('bladder cancer', 9),
#  ('cervical carcinoma', 9),
#  ('ulcerative colitis without inflammation', 9),
#  ('HIV', 9),
#  ('ALL with t(12', 9),
#  ('ALL with hyperdiploid karyotype', 9),
#  ('renal carcinoma', 9),
#  ('Waldenstr\x9ams macroglobulinemia', 9),
#  ('sickle cell anaemia', 9),
#  ('hereditary spherocytosis', 8),
#  ('disease', 8),
#  ('ganglioneuroblastoma', 8),
#  ('T-LGL lymphocytosis', 8),
#  ('ulcerative colitis with inflammation', 8),
#  ('Hutchinson-Gilford Progeria Syndrome', 8),
#  ('villitis', 8),
#  ('malignant peripheral nerve sheath tumor', 8),
#  ('IFTA/inflammation', 8),
#  ('inflamed tonsil', 8),
#  ('gastric carcinoma', 8),
#  ('gulf war illness', 8),
#  ('B-cell chronic lymphocytic leukaemia', 8),
#  ('testicular germ-cell tumor', 8),
#  ('idiopathic pulmonary arterial hypertension', 8),
#  ('bronchioalveolar carcinoma', 8),
#  ('mycosis fungoides', 8),
#  ('mental retardation or developmental delay', 8),
#  ('oropharynx squamous cell carcinoma', 8),
#  ('idiopathic chronic fatigue', 8),
#  ('autosomal dominant monocytopenia', 8),
#  ('facioscapulohumeral muscular dystrophy', 8),
#  ('preeclampsia', 7),
#  ('metastatic melanoma', 7),
#  ('aldosterone-producing adenoma', 7),
#  ('folicular lymphoma', 7),
#  ('thanatophoric dysplasia', 7),
#  ('neuroaxonal injury in cerebral palsy patient', 7),
#  ('gonadotrope tumor', 7),
#  ('chronic malaria', 7),
#  ('fibrosarcoma', 7),
#  ("Freidriech's ataxia", 7),
#  ('atypical carcinoid', 7),
#  ('esophageal squamous cell carcinoma', 6),
#  ('AIDS-related non-Hodgkins lymphoma', 6),
#  ("Graves' disease", 6),
#  ('asthma with exercise induced bronchoconstriction', 6),
#  ('T-cell lymphoma', 6),
#  ('Nijmegen breakage syndrome', 6),
#  ('atopic dermatitis', 6),
#  ('graft-versus host disease', 6),
#  ('benign prostate tumor', 6),
#  ('primary prostate cancer', 6),
#  ('eosinophilic esophagitis', 6),
#  ('lung squamous cell carcinoma', 6),
#  ('AMD', 6),
#  ('bone sarcoma', 6),
#  ('nodular goiter', 6),
#  ("active Crohn's disease", 6),
#  ('sarcoidosis', 6),
#  ('pituitary adenoma', 6),
#  ('Progressive supranuclear palsy', 6),
#  ('germinoma', 6),
#  ('adenomyosis', 6),
#  ('hypopharynx squamous cell carcinoma', 6),
#  ('COPD/non-small cell squamous cell carcinoma', 6),
#  ('extranodal NK/T-Cell lymphoma derived cell line', 6),
#  ('midgut carcinoid', 6),
#  ('hyperplastic polyposis syndrome', 5),
#  ('lymphocytic leukaemia', 5),
#  ('pneumonia/empyema/S. Pneumoniae infection', 5),
#  ('mesothelioma', 5),
#  ('hairy cell leukaemia', 5),
#  ('lepromatous leprosy', 5),
#  ('nasopharyngeal squamous cell carcinoma', 5),
#  ("Huntington's disease", 5),
#  ('glioblastoma with EGFR amplification', 5),
#  ('birch pollen allergy', 5),
#  ('oligodendroglioma', 5),
#  ('previous malaria infection', 5),
#  ('ICA (appearance of autoantibodies against islet cells)', 5),
#  ('HBV/hepatocellular carcinoma', 5),
#  ('anaplastic large cell lymphoma', 5),
#  ('MLL rearrangement', 5),
#  ('rheumatoid arthriris', 5),
#  ('AML with MLL rearrangement', 5),
#  ('pleomorphic liposarcoma', 5),
#  ('adenoma with high-grade dysplasia', 5),
#  ('colon tumor', 4),
#  ('diffusely infiltrating astrocytic glioma', 4),
#  ('nasopharingeal carcinoma', 4),
#  ('COPD/non-small cell adenocarcinoma', 4),
#  ('anaplastic carcinoma', 4),
#  ('pulmonary arterial hypertension', 4),
#  ('anaplastic astrocytoma', 4),
#  ('renal clear cell carcinoma', 4),
#  ('kidney carcinoma', 4),
#  ('non-inflammatory neurological disease', 4),
#  ('schyzophrenia', 4),
#  ('AML/chemotherapy-induced oral mucositis', 4),
#  ('Stevens-Johnson syndrome/toxic epidermal necrolysis', 4),
#  ('myelodysplasia', 4),
#  ('AIDS/activated B-cell-like diffuse large B-cell lymphoma', 4),
#  ('pediatric-high grade glioma/glioblastoma variant', 4),
#  ('Haemophilus ducreyi infection', 4),
#  ('type 1 diabetes longstanding', 4),
#  ('malignant testicular teratoma', 4),
#  ('colorectal cancer - CD', 4),
#  ('metastatic colorectal cancer in liver', 4),
#  ('spinal muscular atrophy', 4),
#  ("Kaposi's sarcoma", 4),
#  ('familial hyperplastic polyposis', 4),
#  ('serous borderline ovarian cancer', 4),
#  ('stress incontinence', 4),
#  ('BRCA1-deficient breast cancer', 4),
#  ('fever/influenza A infection', 4),
#  ('oligodendroglioma (grade 3) with 1p19q codeletion', 4),
#  ('small cell lung carcinoma', 4),
#  ('choroideremia', 4),
#  ('chronic myelogenous leukaemia', 4),
#  ('morbidly obese', 4),
#  ('graft-versus-host disease', 4),
#  ("non active Crohn's disease", 3),
#  ('undifferentiated bone sarcoma', 3),
#  ('myelodisplastic syndrome', 3),
#  ('null cell tumor', 3),
#  ('spina bifida', 3),
#  ('acute malaria', 3),
#  ('cancer', 3),
#  ('non-inflammatory bowel disease', 3),
#  ('myxoid liposarcoma', 3),
#  ('dedifferentiated liposarcoma', 3),
#  ('bipolar disorder', 3),
#  ('carcinoid', 3),
#  ('pituitary tumor', 3),
#  ('in-transit extremity melanoma', 3),
#  ('colorectal cancer - B', 3),
#  ('MCI', 3),
#  ('pituitary adenoma predisposition', 3),
#  ('organ donor', 3),
#  ('metastatic CCRCC', 3),
#  ('type 1 diabetes clinical onset', 3),
#  ('Diamond-Blackfan Anemia', 3),
#  ('cystic fibrosis', 3),
#  ('ileocecal carcinoma', 3),
#  ('head and neck squamous cell carcinoma', 3),
#  ('neuromuscular pain', 3),
#  ('squamous cell lung carcinoma', 3),
#  ('contralateral testicular aplasia', 3),
#  ('chondrosarcoma', 3),
#  ('corticosteroid sensitive asthma', 3),
#  ('corticosteroid resistant asthma', 3),
#  ('ALL with t(1', 3),
#  ('oligodendroglioma (grade 3) with EGFR amplification', 3),
#  ('Williams-Beuren Syndrome', 3),
#  ('type 1 diabetes recent onset', 3),
#  ('extranodal NK/T-Cell lymphoma', 3),
#  ('active ulcerative colitis', 3),
#  ('ganglioneuroma', 3),
#  ('osteomyelitis', 3),
#  ('hydrolethalus syndrome', 3),
#  ('invasive ductal/lobular carcinoma', 3),
#  ('autoimmune polyendocrinopathy-candidiasis-ectodermal dystrophy', 3),
#  ('Pro-B-ALL with t 11q23', 3),
#  ('well-differentiated soft tissue sarcoma', 3),
#  ('type 1 diabetes', 3),
#  ('uterine leiomyoma', 3),
#  ('non-active ulcerative colitis', 3),
#  ('large cell lung cancer', 2),
#  ('atypical ductal hyperplasia', 2),
#  ('highly invasive glioma', 2),
#  ('diseased (bleeding on probing)', 2),
#  ('epitheloidal angiolipoma', 2),
#  ('eosinophilic leukaemia', 2),
#  ('autoimmune lymphoproliferative syndrome', 2),
#  ('cystic fibrosis/chronic rhinosinusitis', 2),
#  ('alveolar cell carcinoma', 2),
#  ('metastatic stomach cancer in liver', 2),
#  ('oligoastrocytoma', 2),
#  ('cytomegalovirus', 2),
#  ('placenta choriocarcinoma', 2),
#  ('germinoma/teratoma', 2),
#  ('pediatric-high grade glioma/pleomorphic xanthoastrocytoma', 2),
#  ('fever/influenza B infection', 2),
#  ('papillary carcinoma', 2),
#  ('Usher syndrome', 2),
#  ('large cell lymphoma', 2),
#  ('mucoepidermoid lung cancer', 2),
#  ('pediatric-high grade glioma/anaplastic oligodendroglioma', 2),
#  ('inflammatory lung disease', 2),
#  ('bilateral cryptorchid', 2),
#  ('non-invasive glioma', 2),
#  ('ejaculatory azoospermia/cryptorchidism', 2),
#  ('Roberts syndrome', 2),
#  ('Alagille syndrome', 2),
#  ('lipoma', 2),
#  ('metastatic mammary carcinoma in liver', 2),
#  ('adult T-cell leukaemia', 2),
#  ("malignant Burkitt's lymphoma", 2),
#  ('lung cancer (pathology not available)', 2),
#  ('indolent mantle cell lymphoma', 2),
#  ('malignant mesothelioma', 2),
#  ('idipathic pulmonary fibrosis', 2),
#  ('pancreatic ductal adenocarcinoma', 2),
#  ('metastatic kidney carcinoma in liver', 2),
#  ('borderline tuberculoid leprosy', 2),
#  ('endometrioid ovarian cancer', 2),
#  ('trachoma', 2),
#  ('metastatic gastrointestinal stromal tumor in liver', 2),
#  ('recurrent glioblastoma multiforme', 2),
#  ('liver adenoma', 2),
#  ('cocoon affected', 2),
#  ('hereditary gingival fibromatosis', 2),
#  ('large cell neuroendocrine carcinoma', 2),
#  ('pediatric-high grade glioma/anaplastic astrocytoma', 2),
#  ('ALL with MLL rearrangement', 2),
#  ('obstruction', 2),
#  ('infiltrating lobular carcinoma', 2),
#  ('apocrine adenocarcinoma', 2),
#  ('Setleis syndrome', 2),
#  ('ovary carcinoma', 1),
#  ('chronic allograft nephropathy grade I', 1),
#  ('splenic marginal zone lymphoma', 1),
#  ('post-transplant', 1),
#  ('germioma/yolk sac tumor', 1),
#  ('apilocytic astrocytoma', 1),
#  ('Brief Psychotic Disorder', 1),
#  ('COPD/giant bullae', 1),
#  ('oligoastrocytoma (grade 3) with EGFR amplification', 1),
#  ('pulmonary tuberculosis', 1),
#  ('immunoblastic large cell lymphoma', 1),
#  ('gastric papillary adenocarcinoma', 1),
#  ('septic arthritis/osteomyelitis/bacteremia/methicillin-sensitive Staphylococcus aureus infection',
#   1),
#  ('follicular hyperplasia', 1),
#  ('ductal carcinoma/lobular carcinoma', 1),
#  ('dominant retinitis pigmentosa', 1),
#  ('NK leukaemia', 1),
#  ('disseminated/methicillin-resistant Staphylococcus aureus infection', 1),
#  ('nodular melanoma', 1),
#  ('inflammation', 1),
#  ('monoclonal gammopathy of undetermined significance', 1),
#  ('malignant pheochromocytoma', 1),
#  ('adenocarcinoma with spindle cell metaplasia', 1),
#  ('tuberous sclerosis', 1),
#  ('lymphoid neoplasm', 1),
#  ("malignant non-Hodgkin's lymphoma", 1),
#  ('osteomyelitis/bacteremia/methicillin-resistant Staphylococcus aureus infection',
#   1),
#  ('diffuse mixed lymphoma', 1),
#  (' myxoid round cell liposarcoma', 1),
#  ('muscular dystrophy', 1),
#  ('pneumonia/bacteremia/S. Pneumoniae infection', 1),
#  ('MLL', 1),
#  ('acute megakaryocytic leukaemia', 1),
#  ('papillary serous ovarian adenocarcinoma', 1),
#  ('esophageal squamous carcinoma', 1),
#  ('intestinal adenocarcinoma', 1),
#  ('oculo-facio-cardio-dental syndrome', 1),
#  ('AIDS/Burkitt lymphoma', 1),
#  ('astrocytoma', 1),
#  ('pneumonia/influenza A infection', 1),
#  ('cecum carcinoma', 1),
#  ('hematoma', 1),
#  ('chronic rhinosinusitis', 1),
#  ('parathyroid tumour', 1),
#  ('teratoma/germ cell tumor', 1),
#  ('osteomyelitis/suppurative arthritis/methicillin-resistant Staphylococcus aureus infection',
#   1),
#  ('encephalitis/influenza A infection', 1),
#  ('adenosquamous carcinoma', 1),
#  ('Rett syndrome', 1),
#  ('Waldenstrom Macroglobulinemia', 1),
#  ('immunodeficiency associated Burkitt lymphoma', 1),
#  ('facial tumor', 1),
#  ('mucinous adenocarcinoma', 1),
#  ('atrial fibrillation', 1),
#  (' bone marrow', 1),
#  ('progressive multiple sclerosis', 1),
#  ('breast medullary carcinoma', 1),
#  ('breast squamous cell carcinoma', 1),
#  ('AIDS/DLBCL', 1),
#  ('NK/T-cell lymphoma', 1),
#  ('fever/upper respiratory infection/influenza A infection', 1),
#  ('lymph node metastasis', 1),
#  ('ovarian papillary serous adenocarcinoma', 1),
#  ('giant cell glioblastoma', 1),
#  ('chronic graft versus host disease', 1),
#  ('disseminated/pneumonia/methicillin-sensitive Staphylococcus aureus infection',
#   1),
#  ('bacteremia/suppurative arthritis/methicillin-resistant Staphylococcus aureus infection',
#   1),
#  ('diffuse large cell lymphoma', 1),
#  ('breast metaplastic carcinoma', 1),
#  ('asymptomatic HIV-1 infection', 1),
#  ('Pro-B-ALL', 1),
#  ('pre-transplant', 1),
#  ('leukemic-state lymphoma', 1),
#  ('sporadic Burkitt lymphoma', 1),
#  ('embryonic carcinoma', 1),
#  ('COPD/emphysema', 1),
#  ('mucoid ductal carcinoma', 1),
#  ('AML-TLS', 1),
#  ('teratoma/yolk sac tumor', 1),
#  ('intracranial arterial aneurysm (unruptured)', 1),
#  ('-', 1),
#  ('fever/upper respiratory infection/influenza B infection', 1),
#  ('pancreatic carcinoma', 1),
#  ('subependymal giant cell astrocytoma', 1),
#  ('systemic juvenile idiopathic arthritis', 1),
#  ('AIDS/GCB-DLBCL', 1),
#  ('graft versus host disease', 1),
#  ('RCC', 1),
#  ('COPD/giant cell tumor', 1),
#  ("extraskeletal Ewing's sarcoma", 1)]

# %%
Counter(df['Characteristics[cell line]']).most_common()
# Out:
# [('  ', 21656),
#  ('MCF-7', 347),
#  ('HeLa', 231),
#  ('HepG2', 210),
#  ('HCT-116', 173),
#  ('A549', 167),
#  ('MDA-MB-231', 145),
#  ('Ishikawa', 144),
#  ('Huh7', 118),
#  ('HEK-293', 99),
#  ('THP-1', 82),
#  ('LNCaP', 79),
#  ('BEAS-2B', 75),
#  ('MCF-10A', 74),
#  ('A2780', 67),
#  ('MSK-Leuk1', 60),
#  ('DU145', 55),
#  ('hBEC', 54),
#  ('ARPE-19', 49),
#  ('U937', 48),
#  ('RPMI-8226', 45),
#  ('H9', 42),
#  ('SH-SY5Y-E', 42),
#  ('HT-29', 41),
#  ('EREB2-5', 41),
#  ('Jurkat', 40),
#  ('HEK-293T', 39),
#  ('A375', 38),
#  ('HT1080', 37),
#  ('Caco-2', 37),
#  ('U2-OS', 36),
#  ('K562', 34),
#  ('U251', 33),
#  ('SK-N-MC', 33),
#  ('HepaRG', 33),
#  ('SW620', 32),
#  ('NCI-H1299', 26),
#  ('BE(2)-C', 26),
#  ('H295R', 25),
#  ('SH-SY5Y-A', 24),
#  ('HK-2', 24),
#  ('Sez-4', 24),
#  ('SH-SY5Y', 23),
#  ('RWPE1', 23),
#  ('HL60', 23),
#  ('Saos-2', 22),
#  ('PC-3', 22),
#  ('IMR-32', 22),
#  ('IMR90', 22),
#  ('MonoMac 6', 21),
#  ('SK-N-SH', 21),
#  ('P493-6', 21),
#  ('BT-474', 19),
#  ('Calu-3 subclone 2B4', 19),
#  ('HEK-TLR2', 18),
#  ('CEM', 17),
#  ('SAOS', 16),
#  ('T47D', 16),
#  ('SKGT4', 15),
#  ('Detroit 562', 15),
#  ('HSC-3', 15),
#  ('MM.1s', 15),
#  ('A375M2', 15),
#  ('HET-1A', 15),
#  ('HepG2/C3A', 15),
#  ('MDA-MB-468', 14),
#  ('MCH58', 14),
#  ('DAOY', 14),
#  ('abl', 14),
#  ('HEK-293H', 14),
#  ('FL', 13),
#  ('H460', 13),
#  ('H1618', 13),
#  ('Calu-6', 13),
#  ('CP-A hTERT', 13),
#  ('IGROV-1', 12),
#  ('SW480', 12),
#  ('Ishikawa H', 12),
#  ('LL24', 12),
#  ('36M2', 12),
#  ('Hec50co', 12),
#  ('TIG3 TERT/deltaB-RAF:ER', 12),
#  ('LI90', 12),
#  ('U373', 12),
#  ('Jurkat/IM-9/Raji/THP-1', 12),
#  ('HaCaT', 12),
#  ('DLD-1', 11),
#  ('U87', 11),
#  ('MT-2', 10),
#  ('I83E95', 10),
#  ('NT2/D1', 10),
#  ('H292', 10),
#  ('U937 PR-9', 10),
#  ('ZR-75-1', 10),
#  ('MT-4', 10),
#  ('Capan-1', 10),
#  ('AGS and MKN-45', 10),
#  ('H929', 10),
#  ('B41', 9),
#  ('GBS6', 9),
#  ('HuT-78', 9),
#  ('Hs683', 9),
#  ('786-O', 9),
#  ('Hec50', 9),
#  ('Calu-3', 9),
#  ('MIA PaCa2', 9),
#  ('MCF-7-FR', 9),
#  ('A431', 9),
#  ('GM5659', 9),
#  ('U266', 9),
#  ('fibroblast derived cell line', 9),
#  ('Panc 1', 9),
#  ('MCF-10A MycER', 9),
#  ('T84', 9),
#  ('SACHI', 9),
#  ('TK6', 8),
#  ('OCUB-M', 8),
#  ('IOSE', 8),
#  ('TaY-E10', 8),
#  ('Calu-1', 8),
#  ('HTR8', 8),
#  ('Reh', 8),
#  ('UROtsa', 8),
#  ('NPrEC', 8),
#  ('MDA-MB-361', 8),
#  ('Hep-3B', 8),
#  ('HTB-58', 8),
#  ('BxPC-3', 8),
#  ('CCRF-CEM-C7R1', 8),
#  ('Raji', 8),
#  ('Ramos', 8),
#  ('CWR22Rv1', 8),
#  ('AsPC-1', 8),
#  ('H1', 8),
#  ('HuT-102', 8),
#  ('hES-T3', 8),
#  ('TaY', 8),
#  ('huvec', 7),
#  ('HCC-1428', 7),
#  ('MRC-5', 7),
#  ('KMS11', 7),
#  ('MDA-MB-436', 7),
#  ('SKOV-3', 7),
#  ('UET-13TR-EWS/ERG', 7),
#  ('L3.6pl', 7),
#  ('HTETOP', 7),
#  ('AGS', 7),
#  ('GM15850', 7),
#  ('MKN-74', 7),
#  ('H720', 7),
#  ('COLO-205', 6),
#  ('PLC/PRF/5', 6),
#  ('CCD-18Co', 6),
#  ('UMCL01-101', 6),
#  ('Awells', 6),
#  ('HMF3A', 6),
#  ('1089 luminal', 6),
#  ('Hotz', 6),
#  ('UT-15', 6),
#  ('U937T', 6),
#  ('OVCA429', 6),
#  ('hTERT-immortalized human mammary epithelial cell;', 6),
#  ('UET-13TR-EWS/FLI1', 6),
#  ('U1752', 6),
#  ('PDB1lox_17', 6),
#  ('PDB1lox_21', 6),
#  ('CCRF-CEM-c1', 6),
#  ('TIG-1', 6),
#  ('FG', 6),
#  ('SH-SY5Y/TrkA', 6),
#  ('WM-266-4', 6),
#  ('LNCaP late passage (LP50)', 6),
#  ('GM15851', 6),
#  ('IM-9', 5),
#  ('C7H2', 5),
#  ('ZL25', 5),
#  ('FaDu', 5),
#  ('MCF-10F', 5),
#  ('HBEC4', 5),
#  ('SU-DHL-4', 5),
#  ('22Rv1', 5),
#  ('H4', 5),
#  ('hESC BG01', 5),
#  ('hTERT-immortalized breast primary epithelial cell;', 5),
#  ('MCF-7-DN-CLIM-TetOff', 5),
#  ('XG', 5),
#  ('BJ', 5),
#  ('hTERT-immortalized BPEC', 5),
#  ('76N RhoA', 5),
#  ('round5 A2780', 5),
#  ('CCD-1079Sk', 5),
#  ('SW2', 5),
#  ('SK-Mel-28', 5),
#  ('HBEC2', 5),
#  ('TF-1', 5),
#  ('MKN-45', 5),
#  ('CAL-51', 4),
#  ('GM15245', 4),
#  ('GM15038', 4),
#  ('GM15226', 4),
#  ('L-1236', 4),
#  ('H125', 4),
#  ('GS-3 clone', 4),
#  ('NPC 5-8F', 4),
#  ('UPN-1', 4),
#  ('SK-N-AS-NmycER', 4),
#  ('SK-MEL-5', 4),
#  ('184B5 MeM', 4),
#  ('H522', 4),
#  ('GM15216', 4),
#  ('CA2', 4),
#  ('PaTu8988t', 4),
#  ('Caov-3', 4),
#  ('Caki-1', 4),
#  ('REC-1', 4),
#  ('HME', 4),
#  ('H9-derived', 4),
#  ('SKM-1', 4),
#  ('H441', 4),
#  ('PCSC-1', 4),
#  ('PreB 697 R4G4', 4),
#  ('HeLa-S3', 4),
#  ('CA1', 4),
#  ('OPM1', 4),
#  ('TGCT-833K', 4),
#  ('TGCT-GCT27', 4),
#  ('Susa', 4),
#  ('Sosp-9607', 4),
#  (' proerythroblast', 4),
#  ('GM15221', 4),
#  ('Tesi', 4),
#  ('NOMO-1', 4),
#  ('GM15036', 4),
#  ('MCF-7:2A', 4),
#  ('BC-3', 4),
#  ('dH1F', 4),
#  ('PCSC-3', 4),
#  ('H82', 4),
#  ('LS2 derived', 4),
#  ('NB4', 4),
#  ('SNT-8', 4),
#  ('Granta-519', 4),
#  ('NZM12', 4),
#  ('GM15213', 4),
#  ('SHEP-Tet21N', 4),
#  ('LOVO', 3),
#  ('BT-474-EI', 3),
#  ('GM15029', 3),
#  ('GM15385', 3),
#  ('A2058', 3),
#  ('NZM15', 3),
#  ('TOV21G', 3),
#  ('HeyA8', 3),
#  ('SCC1', 3),
#  ('1Cc8', 3),
#  (' erythrocyte', 3),
#  ('HSB2', 3),
#  ('BattP12', 3),
#  ('GM15268', 3),
#  ('SNT-13', 3),
#  ('SNT-15', 3),
#  ('C7H2-S15', 3),
#  ('Huh7.5', 3),
#  ('NT-1', 3),
#  ('COLO-201', 3),
#  ('MCF-7R4', 3),
#  ('GM15056', 3),
#  ('5-8F', 3),
#  ('H1819', 3),
#  ('Met5A', 3),
#  ('HBL-2', 3),
#  ('90-8', 3),
#  ('GM15144', 3),
#  ('hf240-NS', 3),
#  ('HeLa clone', 3),
#  ('U87MG', 3),
#  ('HMEC', 3),
#  ('CFT-2', 3),
#  ('HCT-8', 3),
#  ('GM15215', 3),
#  ('HG23', 3),
#  ('6-10B', 3),
#  ('SKOV', 3),
#  ('SK-N-AS', 3),
#  ('HS578T', 3),
#  ('JeKo-1', 3),
#  ('T3ES', 3),
#  ('GM15590', 3),
#  ('Oci-Ly-19', 3),
#  ('hiPS', 3),
#  ('IGROV', 3),
#  ('GM15061', 3),
#  ('HEK-293 clone', 3),
#  ('GM15223', 3),
#  ('C33-A', 3),
#  ('MT-1', 3),
#  ('Kit225', 3),
#  ('T112D', 3),
#  ('PCSC-2', 3),
#  ('H1993', 3),
#  ('GM15242', 3),
#  ('PaTu8988s', 3),
#  ('GM15324', 3),
#  ('KMH2', 3),
#  ('ReNCell', 3),
#  ('HCC-38', 3),
#  ('MEG-01', 3),
#  ('GM15386', 3),
#  ('Con1', 3),
#  ('GS-7 clone', 3),
#  ('H661', 2),
#  ('SK-CO-1', 2),
#  ('HLF-A', 2),
#  ('H23', 2),
#  ('GM15236', 2),
#  ('BT/HerR1.0E clone (Her2-positive BT474)', 2),
#  ('H187', 2),
#  ('Fu97', 2),
#  ('Ptci', 2),
#  ('GM11829', 2),
#  ('GM14464', 2),
#  ('GM14465', 2),
#  ('GM14535', 2),
#  ('GM14536', 2),
#  ('GM14583', 2),
#  ('GM14433', 2),
#  ('GM14453', 2),
#  ('GM14581', 2),
#  ('U87R4', 2),
#  ('UMRC2', 2),
#  ('SKRC54', 2),
#  ('GM', 2),
#  ('CCRF-CEM', 2),
#  ('11A', 2),
#  ('GS-2', 2),
#  ('HGADFN155', 2),
#  ('H358', 2),
#  ('H2122', 2),
#  ('H596', 2),
#  ('Eol1', 2),
#  ('A3-Kawakami', 2),
#  ('SU-DHL-16', 2),
#  ('WSU-FSCCL', 2),
#  ('WS1', 2),
#  ('H1437', 2),
#  ('SK-N-F1', 2),
#  ('GI-ME-N', 2),
#  ('GM07034', 2),
#  ('GM07345', 2),
#  ('GM11830', 2),
#  ('GM11992', 2),
#  ('GM12236', 2),
#  ('GM12248', 2),
#  ('GM12760', 2),
#  ('GM12874', 2),
#  ('GM14504', 2),
#  ('GM14582', 2),
#  ('C7H2-S10', 2),
#  ('UMRC3', 2),
#  ('A1', 2),
#  ('10A', 2),
#  ('HS766t', 2),
#  ('Panc 10.05', 2),
#  ('SA01', 2),
#  ('S462', 2),
#  ('GM03348E', 2),
#  ('KYSE-140', 2),
#  ('SW1573', 2),
#  ('H1651', 2),
#  ('GM15227', 2),
#  ('GM15072', 2),
#  ('TEM2-5', 2),
#  ('BT/HerR0.2J clone (Her2-positive BT474)', 2),
#  ('G179-NS', 2),
#  ('RC-K8', 2),
#  ('SCC-3', 2),
#  ('GM11831', 2),
#  ('GM12005', 2),
#  ('GM12057', 2),
#  ('GM12156', 2),
#  ('GM12750', 2),
#  ('GM12761', 2),
#  ('GM14476', 2),
#  ('GM14502', 2),
#  ('GM14382', 2),
#  ('GM14406', 2),
#  ('GM14409', 2),
#  ('MM.1S', 2),
#  ('C7H2-R3B5', 2),
#  ('SKRC45', 2),
#  ('C1', 2),
#  ('A375SM', 2),
#  ('LS180', 2),
#  ('SKVCR 2.0', 2),
#  ('GS-9', 2),
#  ('GS-3', 2),
#  ('NHDF1', 2),
#  ('PC-3MM2', 2),
#  ('CX-1', 2),
#  ('HOP62', 2),
#  ('HOP92', 2),
#  ('HCC-1143', 2),
#  ('U937 NB4', 2),
#  ('EBV-LCL 721', 2),
#  ('JEG-3', 2),
#  ('BT/HerR1.0C clone (Her2-positive BT474)', 2),
#  ('MHH-PREB-1', 2),
#  ('SU-DHL-1', 2),
#  ('SU-DHL-8', 2),
#  ('LAN-1', 2),
#  ('GM07022', 2),
#  ('GM12003', 2),
#  ('GM12006', 2),
#  ('GM12043', 2),
#  ('GM12145', 2),
#  ('GM14440', 2),
#  ('GM14454', 2),
#  ('GM14477', 2),
#  ('GM14417', 2),
#  ('GM14432', 2),
#  ('GM14478', 2),
#  ('GM14568', 2),
#  ('C7H2-R19F2', 2),
#  ('C7H2-R19E7', 2),
#  ('H322c', 2),
#  ('WIBR7', 2),
#  ('C4-2', 2),
#  ('H209', 2),
#  ('HS683', 2),
#  ('H2009', 2),
#  ('H226', 2),
#  ('H1793', 2),
#  ('H1568', 2),
#  ('SU-DHL-10', 2),
#  ('GM06985', 2),
#  ('GM07056', 2),
#  ('GM12144', 2),
#  ('GM12154', 2),
#  ('GM12239', 2),
#  ('GM12249', 2),
#  ('GM12264', 2),
#  ('GM12815', 2),
#  ('GM12873', 2),
#  ('GM12891', 2),
#  ('GM14569', 2),
#  ('SKRC39', 2),
#  ('A6', 2),
#  ('697', 2),
#  ('GS-7', 2),
#  ('ANBL-6', 2),
#  ('H1703', 2),
#  ('CL-40', 2),
#  ('H1435', 2),
#  ('H2405', 2),
#  ('NU-DUL-1', 2),
#  ('TK', 2),
#  ('GM12812', 2),
#  ('GM14474', 2),
#  ('GM14381', 2),
#  ('GM14506', 2),
#  ('GM14507', 2),
#  ('U87L4', 2),
#  ('C7H2-R9C10', 2),
#  ('KTCL 140', 2),
#  ('iPSC 4', 2),
#  ('SN12C', 2),
#  ('L-428', 2),
#  ('HBEC3', 2),
#  ('H157', 2),
#  ('ST88-14', 2),
#  ('GM08398A', 2),
#  ('GM01652C', 2),
#  ('BT-549', 2),
#  ('A427', 2),
#  ('SHEP-21N', 2),
#  ('YCC7', 2),
#  ('GM11832', 2),
#  ('GM12813', 2),
#  ('GM14448', 2),
#  ('Capan-2', 2),
#  ('1205-Lu', 2),
#  ('OCI AML2', 2),
#  ('RKO', 2),
#  ('H520', 2),
#  ('H647', 2),
#  ('OPM2', 2),
#  ('BJAB', 2),
#  ('Hues9', 2),
#  ('GI-LI-N', 2),
#  ('SK-N-BE2(C)', 2),
#  ('GM11881', 2),
#  ('GM12056', 2),
#  ('GM12717', 2),
#  ('GM14501', 2),
#  ('GM14468', 2),
#  ('GM14521', 2),
#  ('Panc 5.04', 2),
#  ('SKRC47', 2),
#  ('KTCL 26', 2),
#  ('CL1-5', 2),
#  ('IMR-32-DKK1', 2),
#  ('GM03349C', 2),
#  ('HGADFN003', 2),
#  ('H838', 2),
#  ('HOP18', 2),
#  ('H1781', 2),
#  ('Namalwa', 2),
#  ('T3', 2),
#  ('M29', 2),
#  ('GM06993', 2),
#  ('GM07055', 2),
#  ('GM12234', 2),
#  ('GM12762', 2),
#  ('GM12814', 2),
#  ('GM14475', 2),
#  ('GM14503', 2),
#  ('MM.1R', 2),
#  ('HPAF-II', 2),
#  ('SNU5', 2),
#  ('RCC4', 2),
#  ('A375P', 2),
#  ('6a', 2),
#  ('9A', 2),
#  ('LN229', 2),
#  ('H322T', 2),
#  ('HCT-15', 2),
#  ('M12', 2),
#  ('G144-NS', 2),
#  ('GM11994', 2),
#  ('GM11995', 2),
#  ('GM12004', 2),
#  ('GM12875', 2),
#  ('GM14439', 2),
#  ('GM14520', 2),
#  ('10', 2),
#  ('GS-8', 2),
#  ('SNK-6', 2),
#  ('H2030', 2),
#  ('H650', 2),
#  ('EKVX', 2),
#  ('GM15224', 2),
#  ('MCF-7:5C', 2),
#  ('BT/HerR0.2D clone (Her2-positive BT474)', 2),
#  ('U-698-M', 2),
#  ('GM06994', 2),
#  ('GM11840', 2),
#  ('GM14509', 2),
#  ('GM14532', 2),
#  ('GM14533', 2),
#  ('GM14414', 2),
#  ('GM14479', 2),
#  ('H2347', 2),
#  ('LN18', 2),
#  ('H2126', 2),
#  ('HCC-1395', 2),
#  ('TEM4-18', 2),
#  ('GM11839', 2),
#  ('GM12763', 2),
#  ('GM12872', 2),
#  ('GM14405', 2),
#  ('GM14447', 2),
#  ('GM14467', 2),
#  ('U-937', 2),
#  ('KG1', 2),
#  ('8d', 2),
#  ('Panc 3.27', 2),
#  ('RKOAS451', 2),
#  ('KPL-1', 2),
#  ('MDA-MB-435', 2),
#  ('HCC-1937', 2),
#  ('Karpas-1106P', 2),
#  ('RL', 2),
#  ('HGC-27', 2),
#  ('PLC8024', 2),
#  ('GM11993', 2),
#  ('GM12716', 2),
#  ('GM12751', 2),
#  ('GM14455', 2),
#  ('Panc 8.13', 2),
#  ('C7H2-R10E7', 2),
#  ('C7H2-S11', 2),
#  ('C7H2-S12', 2),
#  ('WIBR1', 2),
#  ('DB', 2),
#  ('BJ1', 2),
#  ('HGADFN188', 2),
#  ('H1650', 2),
#  ('GM12044', 2),
#  ('GM12892', 2),
#  ('GM14481', 2),
#  ('PL45', 2),
#  ('H1155', 2),
#  ('H69', 2),
#  ('HP75', 2),
#  ('GM15510', 2),
#  ('LS174T', 2),
#  ('GM07000', 2),
#  ('GM11882', 2),
#  ('GM14480', 2),
#  ('GS-5', 2),
#  ('H1838', 2),
#  ('H1666', 2),
#  ('HCC-2218', 2),
#  ('NU-DHL-1', 2),
#  ('LXFL529', 2),
#  ('Sk-Br-3', 2),
#  ('GM07357', 2),
#  ('GM12155', 2),
#  ('GM14408', 2),
#  ('GM14508', 2),
#  ('GM14584', 2),
#  ('RERF-LC-KJ', 1),
#  ('FU-OV-1', 1),
#  ('CAL-120', 1),
#  ('CAMA-1', 1),
#  ('GM17103', 1),
#  ('GM17214', 1),
#  ('GM17112', 1),
#  ('GM17744', 1),
#  ('GM17218', 1),
#  ('GM17119', 1),
#  ('GM17221', 1),
#  ('GM17136', 1),
#  ('GM17229', 1),
#  ('GM17231', 1),
#  ('GM17790', 1),
#  ('GM17795', 1),
#  ('GM17160', 1),
#  ('GM17155', 1),
#  ('GM17145', 1),
#  ('GM17838', 1),
#  ('GM17166', 1),
#  ('GM17172', 1),
#  ('GM17187', 1),
#  ('GM17276', 1),
#  ('DM636', 1),
#  ('DM467', 1),
#  ('DM602', 1),
#  ('HIGK', 1),
#  ('Toledo', 1),
#  ('AG10941', 1),
#  ('GM12146', 1),
#  ('MKN-1', 1),
#  ('hiPS 3975', 1),
#  ('PDB', 1),
#  ('PDB1lox_5', 1),
#  ('G121', 1),
#  ('HBEC5-KT', 1),
#  ('D36', 1),
#  ('A02', 1),
#  ('D32', 1),
#  ('GS-4', 1),
#  ('888MEL', 1),
#  ('G361', 1),
#  ('Hs695T', 1),
#  ('LOX-IMVI', 1),
#  ('SW1116', 1),
#  ('RERF-LC-AD1', 1),
#  ('BT-483', 1),
#  ('GM17105', 1),
#  ('GM17739', 1),
#  ('GM17216', 1),
#  ('GM17125', 1),
#  ('GM17225', 1),
#  ('GM17126', 1),
#  ('GM17767', 1),
#  ('GM17248', 1),
#  ('GM17808', 1),
#  ('GM17161', 1),
#  ('GM17198', 1),
#  ('DM868', 1),
#  ('DM792', 1),
#  ('DM798', 1),
#  ('KPL-4', 1),
#  ('N2', 1),
#  ('N3', 1),
#  ('SR', 1),
#  ('SU-DHL-5', 1),
#  ('GM06944', 1),
#  ('CCD-8Lu', 1),
#  ('CLS145', 1),
#  ('OCUM1', 1),
#  ('YCC2', 1),
#  ('YCC9', 1),
#  ('NHDF 17914', 1),
#  ('hESC BG03', 1),
#  ('LM2', 1),
#  ('HCC-1396', 1),
#  ('G120', 1),
#  ('SF268', 1),
#  ('ML-8', 1),
#  ('GS-10', 1),
#  ('HDLM-2', 1),
#  ('iPSC 1i', 1),
#  ('HBEC4-KT', 1),
#  ('ME180', 1),
#  ('Hs294T', 1),
#  ('HuPT3', 1),
#  ('LN443', 1),
#  ('HGADFN127', 1),
#  ('VMRCLCD', 1),
#  ('MT-3', 1),
#  ('GM17220', 1),
#  ('GM17238', 1),
#  ('GM17139', 1),
#  ('GM17129', 1),
#  ('GM17768', 1),
#  ('GM17802', 1),
#  ('GM17159', 1),
#  ('GM17192', 1),
#  ('GM17261', 1),
#  ('GM17264', 1),
#  ('GM17282', 1),
#  ('DM738', 1),
#  ('DM443', 1),
#  ('GliNS2', 1),
#  ('RI-1', 1),
#  ('HD90/FE07-142-L1', 1),
#  ('CCD-16Lu', 1),
#  ('LL86', 1),
#  ('IMC-1', 1),
#  ('Mpanc-96', 1),
#  ('Hs746T', 1),
#  ('hiPS 17914 line E', 1),
#  ('G111', 1),
#  ('ME181', 1),
#  ('PLC-PRL', 1),
#  ('MM386', 1),
#  ('D08', 1),
#  ('NB9', 1),
#  ('LNZ308', 1),
#  ('U343', 1),
#  ('ABC1', 1),
#  ('RERF-LC-MS', 1),
#  ('AU565', 1),
#  ('GM17102', 1),
#  ('GM17753', 1),
#  ('GM17240', 1),
#  ('GM17245', 1),
#  ('GM17141', 1),
#  ('GM17227', 1),
#  ('GM17762', 1),
#  ('GM17127', 1),
#  ('GM17792', 1),
#  ('GM17150', 1),
#  ('GM17256', 1),
#  ('GM17805', 1),
#  ('GM17814', 1),
#  ('GM17182', 1),
#  ('CRMel', 1),
#  ('CI-1', 1),
#  ('CCD-13Lu', 1),
#  ('CCD-19Lu', 1),
#  ('iPSC clone 3975.4', 1),
#  ('C7H2-S27', 1),
#  ('hiPS line 1', 1),
#  ('WIBR3', 1),
#  ('PDB1lox_22', 1),
#  ('LM1', 1),
#  ('G84', 1),
#  ('GS-12', 1),
#  ('MM200', 1),
#  ('D40', 1),
#  ('D38', 1),
#  ('R28', 1),
#  ('928MEL', 1),
#  ('LN382', 1),
#  ('HCC-1419', 1),
#  ('ZR-75', 1),
#  ('GM17107', 1),
#  ('GM17117', 1),
#  ('GM17759', 1),
#  ('GM17779', 1),
#  ('GM17148', 1),
#  ('GM17147', 1),
#  ('GM17204', 1),
#  ('GM17156', 1),
#  ('GM17804', 1),
#  ('GM17810', 1),
#  ('GM17168', 1),
#  ('GM17274', 1),
#  ('HS5', 1),
#  ('H1L', 1),
#  ('GliNS1', 1),
#  ('KAI3', 1),
#  ('NK92', 1),
#  ('PEER', 1),
#  ('YCC19', 1),
#  ('M059K', 1),
#  ('G44', 1),
#  ('SCC47', 1),
#  ('ME182', 1),
#  ('HK-Hep1', 1),
#  ('MM649', 1),
#  ('D24', 1),
#  ('CJM', 1),
#  ('MDST8', 1),
#  ('PSN1', 1),
#  ('GOTO', 1),
#  ('UET-13', 1),
#  ('LN464', 1),
#  ('KNS62', 1),
#  ('HT', 1),
#  ('MDA-MB-175', 1),
#  ('DU4475', 1),
#  ('GM17252', 1),
#  ('GM17257', 1),
#  ('GM17789', 1),
#  ('GM17816', 1),
#  ('GM17826', 1),
#  ('GM17165', 1),
#  ('GM17181', 1),
#  ('GM17183', 1),
#  ('GM17267', 1),
#  ('GM17268', 1),
#  ('GM17278', 1),
#  ('GM17284', 1),
#  ('MkTBr', 1),
#  ('DM414', 1),
#  ('DM497', 1),
#  ('DM401p', 1),
#  ('Karpas-422', 1),
#  ('MC116', 1),
#  ('CS-1/PR', 1),
#  ('AG07139', 1),
#  ('AG08046', 1),
#  ('AG09877', 1),
#  ('GM04981', 1),
#  ('SCH', 1),
#  ('A172', 1),
#  ('G140', 1),
#  ('D22', 1),
#  ('MM540', 1),
#  ('GS-6', 1),
#  ('NCR-EW2', 1),
#  ('LP1', 1),
#  ('LN319', 1),
#  ('BCN', 1),
#  ('EFO21', 1),
#  ('GM17734', 1),
#  ('GM17208', 1),
#  ('GM17743', 1),
#  ('GM17237', 1),
#  ('GM17764', 1),
#  ('GM17149', 1),
#  ('GM17793', 1),
#  ('GM17215', 1),
#  ('GM17258', 1),
#  ('GM17157', 1),
#  ('GM17833', 1),
#  ('GM17835', 1),
#  ('GM17164', 1),
#  ('GM17180', 1),
#  ('GM17185', 1),
#  ('GM17188', 1),
#  ('GM17197', 1),
#  ('Sk-Mel-28', 1),
#  ('SU-DHL-6', 1),
#  ('CMK', 1),
#  ('AG11696', 1),
#  ('HFF1', 1),
#  ('Panc 3.03', 1),
#  ('Takigawa', 1),
#  ('G130', 1),
#  ('SF539', 1),
#  ('ML-4', 1),
#  ('EC109', 1),
#  ('D28', 1),
#  ('D29', 1),
#  ('RD-ES', 1),
#  ('LN444', 1),
#  ('HCT-8Sa', 1),
#  ('SC-1', 1),
#  ('MDA-MB-453', 1),
#  ('CAL-1201', 1),
#  ('HCC-1954', 1),
#  ('GM17735', 1),
#  ('GM17754', 1),
#  ('GM17746', 1),
#  ('GM17752', 1),
#  ('GM17761', 1),
#  ('GM17121', 1),
#  ('GM17131', 1),
#  ('GM17253', 1),
#  ('GM17259', 1),
#  ('GM17817', 1),
#  ('GM17177', 1),
#  ('GM17285', 1),
#  ('PRMel', 1),
#  ('DM779', 1),
#  ('DM459', 1),
#  ('MDA-MB-468GFP-LN', 1),
#  ('Farage', 1),
#  ('WI38', 1),
#  ('HCC-1008', 1),
#  ('HCC-1599', 1),
#  ('hiPS 17914 line G', 1),
#  ('pMIP3 line 3', 1),
#  ('G141', 1),
#  ('SW 1783', 1),
#  ('M202R1', 1),
#  ('MM622', 1),
#  ('MM96L', 1),
#  ('R18', 1),
#  ('Colo-829', 1),
#  ('HPAC', 1),
#  ('LS1034', 1),
#  ('GM2036A', 1),
#  ('GM17104', 1),
#  ('GM17114', 1),
#  ('GM17115', 1),
#  ('GM17213', 1),
#  ('GM17255', 1),
#  ('GM17154', 1),
#  ('GM17170', 1),
#  ('GM17196', 1),
#  ('GM17272', 1),
#  ('DM451', 1),
#  ('UW-1', 1),
#  ('DM59', 1),
#  ('H14A', 1),
#  ('Detroit 551', 1),
#  ('AG13145', 1),
#  ('Panc 2.13', 1),
#  ('C7H2-S2', 1),
#  ('MCF-7-G11TamR', 1),
#  ('iPSC 1M', 1),
#  ('HBEC2-E', 1),
#  ('MM608', 1),
#  ('MM415', 1),
#  ('MM603', 1),
#  ('R8', 1),
#  ('Colo-320 HSR', 1),
#  ('Colo-678', 1),
#  ('MeWo', 1),
#  ('Panc 4.03', 1),
#  ('SCCH-196', 1),
#  ('hFOB', 1),
#  ('GM02036A', 1),
#  ('MDA-MB-415', 1),
#  ('GM17205', 1),
#  ('GM17733', 1),
#  ('GM17741', 1),
#  ('GM17113', 1),
#  ('GM17116', 1),
#  ('GM17118', 1),
#  ('GM17110', 1),
#  ('GM17124', 1),
#  ('GM17757', 1),
#  ('GM17239', 1),
#  ('GM17769', 1),
#  ('GM17243', 1),
#  ('GM17223', 1),
#  ('GM17247', 1),
#  ('GM17249', 1),
#  ('GM17246', 1),
#  ('GM17774', 1),
#  ('GM17806', 1),
#  ('GM17263', 1),
#  ('DM422', 1),
#  ('76N', 1),
#  ('H13B', 1),
#  ('N1', 1),
#  ('CS-1', 1),
#  ('AG10049', 1),
#  ('AG13066', 1),
#  ('GM02767', 1),
#  ('CFPAC', 1),
#  ('C7H2-S27(ZR)', 1),
#  ('YCC16', 1),
#  ('G142', 1),
#  ('04-147', 1),
#  ('D25', 1),
#  ('AF6', 1),
#  ('D04', 1),
#  ('MM329', 1),
#  ('HCT-29', 1),
#  ('KM12', 1),
#  ('RPMI-7951', 1),
#  ('NAN', 1),
#  ('GM17780', 1),
#  ('GM17250', 1),
#  ('GM17251', 1),
#  ('GM17800', 1),
#  ('GM17782', 1),
#  ('GM17815', 1),
#  ('GM17163', 1),
#  ('GM17281', 1),
#  ('DM368', 1),
#  ('DM366', 1),
#  ('DM424', 1),
#  ('SK-MEL-31', 1),
#  ('MDA-MB-134VI', 1),
#  ('AG11726', 1),
#  ('AZ521', 1),
#  ('Ist1', 1),
#  ('786-VHL', 1),
#  ('G122', 1),
#  ('G112', 1),
#  ('iPSC 15', 1),
#  ...]

# %%
Counter(df['Characteristics[tissue supergroup]']).most_common()
# Out:
# [('  ', 19200),
#  ('lymphoid', 1205),
#  ('breast', 784),
#  ('colorectal', 750),
#  ('lung', 515),
#  ('adipose tissue', 450),
#  ('liver', 415),
#  ('brain', 387),
#  ('gastric tissue', 289),
#  ('skin', 287),
#  ('cervix', 248),
#  ('vastus lateralis', 246),
#  ('lymphoblastoid', 241),
#  ('prostate', 241),
#  ('peripheral blood', 202),
#  ('endometrium', 181),
#  ('embryonic kidney', 174),
#  ('uterus', 156),
#  ('ovary', 146),
#  ('colonic mucosa', 140),
#  ('pancreas', 94),
#  ('subcutaneous adipose tissue', 82),
#  ('lung/bronchus', 75),
#  ('pleura', 70),
#  ('stomach', 64),
#  ('oral cavity', 60),
#  ('bone', 56),
#  ('bronchus', 54),
#  ('mammary gland', 53),
#  ('retina', 49),
#  ('breast tumor', 42),
#  ('ileal mucosa', 40),
#  ('kidney', 36),
#  ('sarcomatiod', 36),
#  ('pulmonary MALT lymphoma tissue', 32),
#  ('pancreatic islet', 32),
#  ('gastrointestinal tissue', 32),
#  ('bronchial epithelium', 28),
#  ('epidermis', 25),
#  ('adrenal gland/cortex', 25),
#  ('neuroblastic tumor', 24),
#  ('cortex/proximal tubule', 24),
#  ('head and neck', 22),
#  ('blood', 21),
#  ('primary clear-cell renal cell carcinoma', 21),
#  ('cultured epidermis', 20),
#  ('nasal', 20),
#  ('tongue', 18),
#  ('liver sinusoidal endothelium', 18),
#  ('lymphoma tissue', 16),
#  ('esophagus', 15),
#  ('soft tissue sarcoma', 15),
#  ('soft tissue', 14),
#  ('fetal lung', 14),
#  ('cerebellum', 14),
#  ('fibroblast', 14),
#  ('amnion', 13),
#  ('esophageal epithelium', 13),
#  ('testis', 12),
#  ('renal tumor', 11),
#  ('intracranial pediatric germ cell tumor', 11),
#  ('buccal mucosa', 11),
#  ('omental adipose tissue', 10),
#  ('bone marrow', 10),
#  ('central nervous system DLBCL', 9),
#  ('spleen', 8),
#  ('meniscal tissue', 8),
#  ('metastatic RCC', 8),
#  ('urothelium', 8),
#  ('epididymis head segment', 8),
#  ('dorsal root ganglion', 8),
#  ('connective tissue', 8),
#  ('cultured erythroid progenitor', 8),
#  ('bronchoalveolar lavage', 8),
#  ('colon', 7),
#  ('umbilical vein', 7),
#  ('synovial tissue', 7),
#  ('pleural effusion', 6),
#  ('HMLER', 6),
#  ('nucleus pulpsus', 6),
#  ('trachea', 6),
#  ('peritoneal effusion', 6),
#  ('annulus fibrosus', 6),
#  ('hematopoietic and lymphoid', 6),
#  ('breast tumor explant', 5),
#  ('trunk neural crest', 5),
#  ('breast epithelium', 5),
#  ('breast reduction mammoplasty tissue explant', 5),
#  ('epididymis body segment', 5),
#  ('inner cell mass', 5),
#  ('BPLER', 5),
#  ('fetal cortex', 5),
#  ('nasopharyngeal', 5),
#  ('colon tumor', 4),
#  ('nasopharingeal tissue', 4),
#  ('mammary epithelium', 4),
#  ('sinus mucosa', 4),
#  ('cord blood', 4),
#  ('articular cartilage', 4),
#  ('embryonic liver', 3),
#  ('epididymis tail segment', 3),
#  ('pulmonary metastasis of clear-cell renal cell carcinoma', 3),
#  ('mesothelium', 3),
#  ('ileum', 3),
#  ('corpus callosum', 3),
#  ('oral mucosa', 3),
#  ('pharyngeal mucosa', 2),
#  ('parathyroid tissue', 2),
#  ('nasopharingeal', 2),
#  ('neonatal dermal fibroblast', 2),
#  ('adrenal cortex', 2),
#  ('placenta', 2),
#  ('colorectal mucosa', 2),
#  ('engineered neural tissue', 1),
#  (' ', 1),
#  ('cecum', 1),
#  ('coronary', 1),
#  ('embryonic cortex', 1),
#  ('biceps', 1),
#  ('embryonic osteoblast', 1),
#  ('pericardial fluid', 1),
#  ('umbilical cord', 1),
#  ('main corpus', 1),
#  ('testicular diffuse large B-cell lymphoma tissue', 1),
#  ('acute myeloid leukemia sample', 1),
#  ('1', 1),
#  ('forearm', 1),
#  ('pleural fluid', 1),
#  ('thigh', 1)]

# %%
df.index = df['Source Name']

# %%
df.index
# Out:
# Index(['Sample 1', 'Sample 2', 'Sample 3', 'Sample 4', 'Sample 5', 'Sample 6',
#        'Sample 7', 'Sample 8', 'Sample 9', 'Sample 10',
#        ...
#        'Sample 27878', 'Sample 27879', 'Sample 27880', 'Sample 27881',
#        'Sample 27882', 'Sample 27883', 'Sample 27884', 'Sample 27885',
#        'Sample 27886', 'Sample 27887'],
#       dtype='object', name='Source Name', length=27887)

# %% [markdown]
# ## Check the sampling situation in the test data

# %% [markdown]
# A few good candidates are: acute myeloid leukaemia, breast cancer (partcularly breast adenocarcinoma) or other adenocarcinoma type. The next task is to figure out whether some experiments have more samples and how the sample look like in only test data sets.

# %%
test_df = pd.read_pickle('/mnt/dzl_bioinf/binliu/deepRNA/data_all_samples/gene_level_train_test/all_samples_gene_level_test.pkl')

# %%
test_df.index
# Out:
# Index(['Sample 1633', 'Sample 11588', 'Sample 11771', 'Sample 8189',
#        'Sample 25499', 'Sample 12023', 'Sample 13689', 'Sample 10572',
#        'Sample 3420', 'Sample 2882',
#        ...
#        'Sample 6154', 'Sample 14011', 'Sample 27307', 'Sample 1905',
#        'Sample 20540', 'Sample 19970', 'Sample 10688', 'Sample 25562',
#        'Sample 23709', 'Sample 22715'],
#       dtype='object', name='CompositeSequence Identifier', length=2787)

# %%
annotation_test_sub = df[df.index.isin(test_df.index)]

# %%
annotation_test_sub.shape
# Out:
# (2787, 30)

# %%
df.shape
# Out:
# (27887, 30)

# %%
test_df.shape
# Out:
# (2787, 23375)

# %%
Counter(annotation_test_sub['Characteristics[disease]']).most_common()
# Out:
# [('normal', 904),
#  ('acute myeloid leukaemia', 105),
#  ('chronic lymphocytic leukaemia', 78),
#  ('breast cancer', 73),
#  ('multiple myeloma', 52),
#  ('diffuse large B-cell lymphoma', 51),
#  ('breast adenocarcinoma', 49),
#  ('ovarian carcinoma', 39),
#  ('colorectal adenocarcinoma', 38),
#  ('hepatocellular carcinoma', 37),
#  ('neuroblastoma', 34),
#  ('gastric cancer', 33),
#  ('melanoma', 33),
#  ('T-ALL', 29),
#  ('lung adenocarcinoma', 29),
#  ('multiple sclerosis or clinically isolated syndrome', 26),
#  ('obesity', 26),
#  ('Pre-B-ALL/c-ALL', 25),
#  ('cervical adenocarcinoma', 23),
#  ('asthma', 23),
#  ('NSCLC', 22),
#  ('myeloma', 22),
#  ('glioblastoma', 21),
#  ('periodontitis', 20),
#  ('myelodysplastic syndrome', 19),
#  ('primary breast tumor', 17),
#  ('endometrial adenocarcinoma', 17),
#  ('colon carcinoma', 16),
#  ('lung cancer', 16),
#  ('colon adenocarcinoma', 16),
#  ('acute myeloid leukaemia ', 16),
#  ('no rejection', 16),
#  ('pancreatic cancer', 15),
#  ('carcinoma', 14),
#  ('allograft rejection', 14),
#  ('acute monocytic leukaemia', 14),
#  ('osteosarcoma', 13),
#  ('breast fibrocystic disease', 13),
#  ('septic shock', 12),
#  ('chronic myeloid leukaemia', 12),
#  ('precursor B-cell acute lymphoblastic leukaemia', 11),
#  ('undifferentiated sarcoma', 11),
#  ('ALL', 11),
#  ('ovarian adenocarcinoma', 11),
#  ("Crohn's disease", 11),
#  ('ulcerative colitis', 11),
#  ('AML/other abnormalities', 10),
#  ('pediatric T-ALL', 10),
#  ('schizophrenia', 9),
#  ('peripheral T-cell lymphoma', 9),
#  ('irritable bowel syndrome', 9),
#  ('HCV/hepatocellular carcinoma', 9),
#  ('prostate cancer', 8),
#  ('leiomyoma', 8),
#  ('prostate adenocarcinoma', 8),
#  ('leiomyosarcoma', 8),
#  ('autism spectrum disorder', 8),
#  ('meningioma', 7),
#  ('childhood B-cell precursor ALL', 7),
#  ('sepsis', 7),
#  ('c-ALL', 7),
#  ('gastrointestinal stromal tumor', 7),
#  ("Ewing's sarcoma", 7),
#  ('colorectal cancer', 6),
#  ('high-grade prostatic intraepithelial neoplasia', 6),
#  ('acute graft-versus-host disease', 6),
#  ('colorectal adenoma', 6),
#  ('COPD', 6),
#  ('osteoarthritis', 6),
#  ('breast ductal adenocarcinoma', 6),
#  ('glioma', 6),
#  ('burn', 6),
#  ('ductal carcinoma', 6),
#  ('lung fibrosarcoma', 6),
#  ('erythroleukaemia', 5),
#  ('B-ALL', 5),
#  ('pilocytic astrocytoma', 5),
#  ('diffuse histiocytic lymphoma', 5),
#  ('meningococcal sepsis', 5),
#  ('biliary atresia', 5),
#  ('prostate carcinoma', 5),
#  ('ependymoma', 5),
#  ('pediatric acute leukaemia', 5),
#  ('clinically isolated syndrome', 5),
#  ('endometriosis', 5),
#  ('breast carcinoma/cystic change', 5),
#  ('invasive ductal carcinoma', 5),
#  ('adrenocortical carcinoma', 5),
#  ('moderate chronic allograft nephropathy', 5),
#  ('kidney transplant recipient', 5),
#  ("Job's syndrome", 4),
#  ('multiple sclerosis', 4),
#  ('lobular carcinoma', 4),
#  ('malignant melanoma', 4),
#  ('B-cell lymphoma', 4),
#  ('acute lymphoblastic leukaemia', 4),
#  ('benign prostatic hyperplasia', 4),
#  ('renal cell carcinoma', 4),
#  ('clear-cell renal cell carcinoma', 4),
#  ('serous epithelial ovarian cancer', 4),
#  ('psoriasis', 3),
#  ('sarcoma', 3),
#  ('cervical cancer', 3),
#  ('hepatitis C virus-induced hepatocellular carcinoma', 3),
#  ('desmoplastic cerebellar medulloblastoma', 3),
#  ('breast ductal carcinoma', 3),
#  ('liposarcoma', 3),
#  ('infiltrating ductal carcinoma', 3),
#  ('rheumatoid arthritis', 3),
#  ('gastric adenocarcinoma', 3),
#  ('adenocarcinoma', 3),
#  ('HIV-1', 3),
#  ('metastatic prostate cancer', 3),
#  ('undifferentiated soft tissue sarcoma', 3),
#  ('moderately differentiated head and neck squamous cell carcinoma', 3),
#  ('hip arthroplasty', 3),
#  ('prolapse', 3),
#  ('mycosis fungoide (cutaneus T-cell lymphoma)', 3),
#  ('unilateral cryptorchid', 3),
#  ('AMD', 3),
#  ('T-cell/histiocyte rich B-cell lymphoma', 3),
#  ('hepatoma', 3),
#  ('juvenile myelomonocytic leukaemia', 3),
#  ('AML(FAB-M0)', 3),
#  ('pancreatic adenocarcinoma', 3),
#  ('Sjogren syndrome', 3),
#  ('renal disease', 3),
#  ('Cornelia de Lange Syndrome', 3),
#  ('lung anaplastic carcinoma', 3),
#  ('type 2 diabetes mellitus', 3),
#  ('mild chronic allograft nephropathy', 3),
#  ('pre-diabetes', 3),
#  ('AML/MLL', 3),
#  ('dilated cardiomyopathy', 3),
#  ('diffuse glioma', 3),
#  ('ALL without MLL rearrangement', 3),
#  ('esophageal adenocarcinoma', 2),
#  ('endometrial cancer', 2),
#  ('ulcerative colitis with inflammation', 2),
#  ('celiac', 2),
#  ('ganglioneuroblastoma', 2),
#  ('renal adenocarcinoma', 2),
#  ('scleroderma without pulmonary hypertension', 2),
#  ("Barret's syndrome", 2),
#  ('oral cavity squamous cell carcinoma', 2),
#  ('lymphoma', 2),
#  ('common ALL', 2),
#  ('chronic malaria', 2),
#  ('rectal adenocarcinoma', 2),
#  ('CCRCC', 2),
#  ('chronic fatigue', 2),
#  ('soft tissue sarcoma', 2),
#  ('ALL with hyperdiploid karyotype', 2),
#  ('ileocecal carcinoma', 2),
#  ('atopy', 2),
#  ('nonsyndromic sagittal synostosis', 2),
#  ('Progressive supranuclear palsy', 2),
#  ('thalassemia', 2),
#  ('adenoma', 2),
#  ('Burkitt lymphoma', 2),
#  ('Kawasaki disease', 2),
#  ('ovarian cancer', 2),
#  ('head and neck cancer', 2),
#  ('non-invasive glioma', 2),
#  ('well differentiated head and neck squamous cell carcinoma', 2),
#  ('glioblastoma multiforme', 2),
#  ('oligoarticular juvenile idiopathic arthritis', 2),
#  ('familial hyperplastic polyposis', 2),
#  ('colon cancer', 2),
#  ('breast carcinoma', 2),
#  ('pituitary tumor', 2),
#  ('severe chronic allograft nephropathy', 2),
#  ('Pro-B-ALL/MLL', 2),
#  ('renal cancer', 2),
#  ('colorectal carcinoma', 2),
#  ("Parkinson's disease", 2),
#  ("Huntington's disease", 2),
#  ('ischemic cardiomyopathy', 2),
#  ('nasopharyngeal carcinoma', 2),
#  ('AML without MLL rearrangement', 2),
#  ('inflamed tonsil', 2),
#  ('autosomal dominant monocytopenia', 2),
#  ('primary unilateral non-metastatic breast cancer', 2),
#  ('nickel allergy', 2),
#  ('neuroblastoma (Ewing sarcoma)', 2),
#  ('vessel ischemic heart disease', 2),
#  ('extranodal NK/T-cell lymphoma', 2),
#  ('myelodysplastic syndrome/refractory anemia with ringed sideroblasts', 2),
#  ('diarrhea-irritable bowel syndrome', 2),
#  ('ATL', 2),
#  ('squamous cell carcinoma', 2),
#  ('fetal adenoma', 2),
#  ('tongue squamous cell carcinoma', 2),
#  ('alveolar soft-part sarcoma', 2),
#  ('cervical carcinoma', 2),
#  ('hyperplastic polyp', 2),
#  ('rhabdomyosarcoma', 2),
#  ('Thompson disease', 2),
#  ('pediatric-high grade glioma/anaplastic astrocytoma', 2),
#  ('pulmonary MALT lymphoma', 2),
#  ('pharyngeal carcinoma', 2),
#  ('Apert syndrome', 2),
#  ('ovary carcinoma', 1),
#  ('diffusely infiltrating astrocytic glioma', 1),
#  ('pneumonia/empyema/S. Pneumoniae infection', 1),
#  ('COPD/giant bullae', 1),
#  ('neuroepithelioma', 1),
#  ("Graves' disease", 1),
#  ('testicular diffuse large B-cell lymphoma', 1),
#  ('lepromatous leprosy', 1),
#  ('myelodysplastic syndrome/refractory anemia', 1),
#  ('renal clear cell carcinoma', 1),
#  ('carcinoid', 1),
#  ('alveolar cell carcinoma', 1),
#  ('T-LGL lymphocytosis', 1),
#  ("chronic Hodgkin's lymphoma", 1),
#  ('non-small cell lung cancer', 1),
#  ('MALT lymphoma', 1),
#  ('familial hypercholesterolemia', 1),
#  ('acute malaria', 1),
#  ('cutaneous T-cell lymphoma', 1),
#  ('organ donor', 1),
#  ('malignant testicular teratoma', 1),
#  ('atopic dermatitis', 1),
#  ('myelodisplastic syndrome', 1),
#  ('bladder cancer', 1),
#  ('ALL with t(12', 1),
#  ('large cell lymphoma', 1),
#  ('lung squamous cell carcinoma', 1),
#  ('gonadotrope tumor', 1),
#  ('vulvar intraepithelial neoplasia', 1),
#  ('osteomyelitis/bacteremia/methicillin-resistant Staphylococcus aureus infection',
#   1),
#  ('glioblastoma with EGFR amplification', 1),
#  ('lung carcinoma', 1),
#  ('primary glioblastoma', 1),
#  ('non-Hodgkins lymphoma', 1),
#  ('juvenile idiopathic arthritis', 1),
#  ('bipolar disorder', 1),
#  ('Waldenstr\x9ams macroglobulinemia', 1),
#  ("Pick's disease", 1),
#  ('larynx squamous cell carcinoma', 1),
#  ('CNS affected', 1),
#  ('systemic inflammatory response syndrome', 1),
#  ('contralateral testicular aplasia', 1),
#  ('mycosis fungoides', 1),
#  ('serous borderline ovarian cancer', 1),
#  ('subclinical interstitial fibrosis', 1),
#  ('her2+ breast cancer', 1),
#  ('AML with t 11q23', 1),
#  ("nodular lymphocyte predominant Hodgkin's lymphoma", 1),
#  ('basal-like breast cancer', 1),
#  ('stress incontinence', 1),
#  ('medulloblastoma', 1),
#  ('facioscapulohumeral muscular dystrophy', 1),
#  ('pre B-ALL', 1),
#  ('gastric carcinoma', 1),
#  ('follicular adenoma', 1),
#  ('angioimmunoblastic T-cell lymphoma', 1),
#  ('B-cell chronic lymphocytic leukaemia', 1),
#  ('not applicable', 1),
#  ('unknown', 1),
#  ('HeLa cell contamination', 1),
#  ('AML with MLL rearrangement', 1),
#  ('acyanotic Tetralogy of Fallot', 1),
#  ('highly invasive glioma', 1),
#  ('bronchopulmonary dysplasia', 1),
#  ('Soetre-Chotzen syndrome', 1),
#  ('poorly differentiated head and neck squamous cell carcinoma', 1),
#  ('adrenocortical tumor', 1),
#  ('mixture', 1),
#  ('differentiated liposarcoma', 1),
#  ('pleomorphic liposarcoma', 1),
#  ('colon adenoma', 1),
#  ('papillary thyroid cancer', 1),
#  ('fever/influenza A infection', 1),
#  ('malignant pluripotent embryonal carcinoma', 1),
#  ('ejaculatory azoospermia/idiopathic infertility', 1),
#  ('nodal peripheral T-cell lymphoma', 1),
#  ('HIV', 1),
#  ('leukaemia', 1),
#  ('midgut carcinoid', 1),
#  ('liver mesenchymal tumor', 1),
#  ("Kaposi's sarcoma", 1),
#  ('bronchioalveolar carcinoma', 1),
#  ('IFTA', 1),
#  ('autoimmune polyendocrinopathy-candidiasis-ectodermal dystrophy', 1),
#  ('myelodysplastic syndrome/refractory anemia with excess blasts', 1),
#  ('hereditary gingival fibromatosis', 1),
#  ('graft-versus-host disease', 1),
#  ('follicular carcinoma', 1),
#  ('Nijmegen breakage syndrome', 1),
#  ('nasopharingeal carcinoma', 1),
#  ('high risk B-precurser ALL', 1),
#  ('HCV', 1),
#  ('ICA (appearance of autoantibodies against islet cells)', 1),
#  ('breast metaplastic carcinoma', 1),
#  ('interstitial cystitis', 1),
#  ('myelodysplasia', 1),
#  ('angina/coronary atherosclerosis', 1),
#  ('malignant peripheral nerve sheath tumor', 1),
#  ('chronic myelogenous leukaemia', 1),
#  ('hydrolethalus syndrome', 1),
#  ('diseased (bleeding on probing)', 1),
#  ('recessive retinitis pigmentosa', 1),
#  ('eosinophilic leukaemia', 1),
#  ('small cell lung cancer', 1),
#  ('mesothelioma', 1),
#  ("active Crohn's disease", 1),
#  ('uterine fibroid', 1),
#  ('previous malaria infection', 1),
#  ('Pro-B-ALL with t 11q23', 1),
#  ('non-basal like breast cancer', 1),
#  ('nodular goiter', 1),
#  ('hypopharynx squamous cell carcinoma', 1),
#  ('-', 1),
#  ('conventional mantle cell lymphoma', 1),
#  ('renal oncocytoma', 1),
#  ('basal cell carcinoma', 1),
#  ('Muenke syndrome', 1),
#  ('monoclonal gammopathy of unknown significance', 1),
#  ('type 2 diabetes', 1),
#  ('polycystic ovary syndrome', 1),
#  ('T-cell leukaemia', 1),
#  ('ALL with MLL rearrangement', 1),
#  ('scleroderma with pulmonary hypertension', 1),
#  ('acute promyelocytic leukaemia', 1),
#  ('  ', 1)]

# %%
Counter(annotation_test_sub['Characteristics[tissue supergroup]']).most_common()
# Out:
# [('  ', 1900),
#  ('lymphoid', 107),
#  ('colorectal', 83),
#  ('breast', 80),
#  ('lung', 51),
#  ('adipose tissue', 43),
#  ('liver', 42),
#  ('brain', 39),
#  ('gastric tissue', 31),
#  ('vastus lateralis', 28),
#  ('skin', 26),
#  ('cervix', 25),
#  ('lymphoblastoid', 24),
#  ('prostate', 24),
#  ('colonic mucosa', 22),
#  ('endometrium', 18),
#  ('peripheral blood', 17),
#  ('uterus', 16),
#  ('embryonic kidney', 15),
#  ('ovary', 14),
#  ('pancreas', 11),
#  ('subcutaneous adipose tissue', 10),
#  ('stomach', 8),
#  ('lung/bronchus', 8),
#  ('pleura', 7),
#  ('bronchus', 7),
#  ('bone', 6),
#  ('kidney', 6),
#  ('oral cavity', 6),
#  ('mammary gland', 5),
#  ('cortex/proximal tubule', 5),
#  ('breast tumor', 5),
#  ('retina', 5),
#  ('pancreatic islet', 4),
#  ('adrenal gland/cortex', 4),
#  ('cerebellum', 3),
#  ('epidermis', 3),
#  ('gastrointestinal tissue', 3),
#  ('primary clear-cell renal cell carcinoma', 3),
#  ('bronchial epithelium', 3),
#  ('ileal mucosa', 3),
#  ('blood', 3),
#  ('esophagus', 2),
#  ('esophageal epithelium', 2),
#  ('central nervous system DLBCL', 2),
#  ('soft tissue sarcoma', 2),
#  ('ileum', 2),
#  ('sarcomatiod', 2),
#  ('neuroblastic tumor', 2),
#  ('metastatic RCC', 2),
#  ('mammary epithelium', 2),
#  ('liver sinusoidal endothelium', 2),
#  ('tongue', 2),
#  ('soft tissue', 2),
#  ('omental adipose tissue', 2),
#  ('connective tissue', 2),
#  ('nucleus pulpsus', 2),
#  ('cultured epidermis', 2),
#  ('pulmonary MALT lymphoma tissue', 2),
#  ('head and neck', 2),
#  ('breast epithelium', 1),
#  ('urothelium', 1),
#  ('mesothelium', 1),
#  ('adrenal cortex', 1),
#  ('testis', 1),
#  ('breast tumor explant', 1),
#  ('nasal', 1),
#  ('coronary', 1),
#  ('dorsal root ganglion', 1),
#  ('buccal mucosa', 1),
#  ('biceps', 1),
#  ('embryonic osteoblast', 1),
#  ('trunk neural crest', 1),
#  ('HMLER', 1),
#  ('epididymis head segment', 1),
#  ('amnion', 1),
#  ('fetal lung', 1),
#  ('E-GEOD-6863', 1),
#  ('E-MEXP-1601', 1),
#  ('E-MEXP-2276', 1),
#  ('E-MEXP-2556', 1),
#  ('4_NP.CEL', 1)]

# %% [markdown]
# Check whether some of the samples happen to overlap between the diseases/ organs of interest and have a reasonable number of samples in a good data set

# %%
test_anno = Counter(annotation_test_sub['Comment [ArrayExpress accession]']).most_common()

# %%
for sample_nr in test_anno:
    tem_sub1 = annotation_test_sub[annotation_test_sub['Comment [ArrayExpress accession]'] == sample_nr[0]]
    print(sample_nr[0] + ', ' + str(Counter(tem_sub1['Characteristics[disease]'])) \
        + '\n' + str(Counter(tem_sub1['Characteristics[organism part]'])))
# Out:
# E-GEOD-13159, Counter({'chronic lymphocytic leukaemia': 42, 'Pre-B-ALL/c-ALL': 25, 'T-ALL': 16, 'AML/other abnormalities': 10, 'acute myeloid leukaemia': 9, 'chronic myeloid leukaemia': 6, 'myelodysplastic syndrome': 3, 'ALL': 3, 'AML/MLL': 3, 'Pro-B-ALL/MLL': 2})
# Counter({'bone marrow': 119})
# array assay, Counter({'normal': 44, 'acute myeloid leukaemia': 6, 'lung adenocarcinoma': 2, 'hepatitis C virus-induced hepatocellular carcinoma': 2, 'myelodisplastic syndrome': 1, 'ALL with t(12': 1, 'AML with t 11q23': 1, "Crohn's disease": 1, 'breast ductal adenocarcinoma': 1, 'not applicable': 1, 'ejaculatory azoospermia/idiopathic infertility': 1, 'rheumatoid arthritis': 1, 'HCV': 1, 'Pro-B-ALL with t 11q23': 1, '-': 1, '  ': 1})
# Counter({'lung': 14, 'gingival papillae': 9, '  ': 9, 'skin': 9, 'liver': 5, 'breast': 4, 'bone marrow': 3, 'prostate': 2, 'colon': 2, 'pancreas': 2, 'blood': 1, 'descending colon': 1, 'mammary epithelium': 1, 'testis': 1, 'stomach': 1, 'knee': 1, 'bone': 1})
# E-GEOD-7307, Counter({'normal': 33, 'breast adenocarcinoma': 3, 'endometriosis': 2, 'benign prostatic hyperplasia': 1, 'breast cancer': 1, 'rheumatoid arthritis': 1, 'uterine fibroid': 1, 'prostate cancer': 1})
# Counter({'myometrium': 3, 'prostate': 3, 'breast': 3, 'spinal cord': 2, 'endometrium/ovary': 2, 'mammary gland': 2, 'endometrium': 2, 'temporal lobe': 1, 'corpus callosum': 1, 'trigeminal ganglion': 1, 'dorsal root ganglion': 1, 'midbrain': 1, 'heart atrium': 1, 'thalamus': 1, 'adipose tissue': 1, 'parietal lobe': 1, 'penis': 1, 'peripheral blood': 1, 'nipple': 1, 'accumbens': 1, 'bronchus': 1, 'amygdala': 1, 'spleen': 1, 'cerebellum': 1, '  ': 1, 'ventral tegmental area': 1, 'trachea': 1, 'synovial membrane': 1, 'umbilical vein': 1, 'occipital lobe': 1, 'hippocampus': 1, 'kidney cortex': 1, 'brain': 1})
# E-GEOD-15061, Counter({'acute myeloid leukaemia ': 16, 'myelodysplastic syndrome': 16, 'normal': 10})
# Counter({'bone marrow': 42})
# E-GEOD-8052, Counter({'asthma': 22, 'normal': 15})
# Counter({'  ': 37})
# E-GEOD-14468, Counter({'acute myeloid leukaemia': 34})
# Counter({'  ': 34})
# E-GEOD-9891, Counter({'ovarian carcinoma': 33})
# Counter({'ovary': 33})
# E-GEOD-13070, Counter({'normal': 31})
# Counter({'skeletal muscle': 24, 'abdomen': 7})
# E-GEOD-21374, Counter({'no rejection': 16, 'allograft rejection': 14})
# Counter({'kidney allograft': 30})
# E-GEOD-16214, Counter({'multiple sclerosis or clinically isolated syndrome': 26})
# Counter({'peripheral blood': 26})
# E-MTAB-54, Counter({'obesity': 17, 'normal': 7, 'unknown': 1})
# Counter({'blood': 12, 'gluteal fat': 7, 'abdominal fat': 6})
# E-GEOD-23120, Counter({'normal': 24})
# Counter({'peripheral blood': 24})
# E-GEOD-14333, Counter({'colorectal adenocarcinoma': 24})
# Counter({'colon': 24})
# E-GEOD-21050, Counter({'undifferentiated sarcoma': 11, 'leiomyosarcoma': 8, 'sarcoma': 3, 'liposarcoma': 2})
# Counter({'extremity': 15, 'internal trunk': 5, 'trunk wall': 4})
# E-GEOD-3526, Counter({'normal': 23})
# Counter({'myometrium': 2, 'hypothalamus': 1, 'parietal lobe': 1, 'subthalamic nucleus': 1, 'cervix': 1, 'tongue': 1, 'frontal lobe': 1, 'vestibular nuclei superior': 1, 'artery': 1, '  ': 1, 'nodose nucleus': 1, 'ganglia': 1, 'vulva': 1, 'medulla': 1, 'urethra': 1, 'substantia nigra': 1, 'heart ventricle': 1, 'hippocampus': 1, 'tonsil': 1, 'putamen': 1, 'vagina': 1, 'cerebral cortex': 1})
# E-GEOD-15459, Counter({'gastric cancer': 23})
# Counter({'  ': 23})
# E-GEOD-10843, Counter({'colon adenocarcinoma': 5, 'NSCLC': 3, 'ileocecal carcinoma': 2, 'colon cancer': 2, 'B-cell lymphoma': 2, 'ovary carcinoma': 1, 'alveolar cell carcinoma': 1, 'lung carcinoma': 1, 'lung cancer': 1, 'ovarian adenocarcinoma': 1, 'bronchioalveolar carcinoma': 1, 'lung adenocarcinoma': 1, 'mesothelioma': 1})
# Counter({'lung': 9, 'colon': 7, 'ovary': 2, 'ileum': 2, 'lymph node': 1, 'peritoneum': 1})
# E-GEOD-11318, Counter({'diffuse large B-cell lymphoma': 22})
# Counter({'lymph node': 22})
# E-GEOD-19784, Counter({'multiple myeloma': 21})
# Counter({'bone marrow': 21})
# E-GEOD-11135, Counter({'hepatocellular carcinoma': 8, 'breast adenocarcinoma': 7, 'acute myeloid leukaemia': 3, 'chronic lymphocytic leukaemia': 2, 'chronic myeloid leukaemia': 1})
# Counter({'liver': 8, 'breast': 7, '  ': 6})
# E-GEOD-17855, Counter({'acute myeloid leukaemia': 21})
# Counter({'bone marrow or peripheral blood': 21})
# E-GEOD-16134, Counter({'periodontitis': 20})
# Counter({'gingival papillae': 20})
# E-GEOD-12276, Counter({'breast cancer': 20})
# Counter({'primary breast tumor': 20})
# E-GEOD-16879, Counter({'ulcerative colitis': 8, "Crohn's disease": 8, 'normal': 2})
# Counter({'  ': 18})
# E-GEOD-26863, Counter({'multiple myeloma': 18})
# Counter({'bone marrow': 18})
# E-TABM-325, Counter({'normal': 18})
# Counter({'  ': 18})
# E-GEOD-19519, Counter({'normal': 17})
# Counter({'  ': 17})
# E-GEOD-23177, Counter({'primary breast tumor': 17})
# Counter({'breast': 17})
# E-GEOD-21653, Counter({'breast cancer': 17})
# Counter({'breast': 17})
# E-GEOD-11882, Counter({'normal': 15})
# Counter({'superior frontal gyrus': 5, 'postcentral gyrus': 4, 'hippocampus': 3, 'entorhinal cortex': 3})
# E-GEOD-11375, Counter({'normal': 15})
# Counter({'blood': 15})
# E-TABM-176, Counter({'irritable bowel syndrome': 9, 'normal': 4})
# Counter({'sigmoid colon mucosa': 13})
# E-GEOD-15935, Counter({'hepatocellular carcinoma': 13})
# Counter({'liver': 13})
# E-GEOD-10780, Counter({'normal': 12, 'invasive ductal carcinoma': 1})
# Counter({'breast duct': 12, 'breast': 1})
# E-GEOD-10846, Counter({'diffuse large B-cell lymphoma': 13})
# Counter({'lymph node': 13})
# E-GEOD-16237, Counter({'neuroblastoma': 13})
# Counter({'  ': 13})
# E-GEOD-19188, Counter({'NSCLC': 8, 'normal': 4})
# Counter({'lung': 12})
# E-GEOD-19743, Counter({'normal': 6, 'burn': 6})
# Counter({'peripheral blood': 12})
# E-GEOD-19475, Counter({'precursor B-cell acute lymphoblastic leukaemia': 11})
# Counter({'  ': 11})
# E-GEOD-24223, Counter({'normal': 11})
# Counter({'peripheral blood': 10, 'whole blood': 1})
# E-GEOD-8507, Counter({'normal': 7, "Job's syndrome": 4})
# Counter({'whole blood': 8, 'peripheral blood': 3})
# E-TABM-763, Counter({'chronic lymphocytic leukaemia': 11})
# Counter({'peripheral blood': 11})
# E-GEOD-11869, Counter({'endometrial adenocarcinoma': 11})
# Counter({'uterus': 11})
# E-TABM-1029, Counter({'acute myeloid leukaemia': 11})
# Counter({'bone marrow': 11})
# E-MTAB-317, Counter({'myeloma': 10, 'monoclonal gammopathy of unknown significance': 1})
# Counter({'bone marrow': 11})
# E-GEOD-12662, Counter({'acute myeloid leukaemia': 7, 'lymphoma': 2, 'normal': 1})
# Counter({'bone marrow': 7, 'pleura': 2, '  ': 1})
# E-GEOD-13933, Counter({'normal': 10})
# Counter({'small airways': 6, 'trachea': 4})
# E-GEOD-16391, Counter({'breast cancer': 10})
# Counter({'breast': 10})
# E-MEXP-1824, Counter({'acute graft-versus-host disease': 6, 'normal': 4})
# Counter({'blood': 10})
# E-GEOD-11348, Counter({'normal': 10})
# Counter({'nose': 10})
# E-GEOD-5460, Counter({'ductal carcinoma': 6, 'breast cancer': 2, 'lobular carcinoma': 2})
# Counter({'breast': 10})
# E-GEOD-10609, Counter({'pediatric T-ALL': 10})
# Counter({'  ': 10})
# E-GEOD-11917, Counter({'normal': 10})
# Counter({'  ': 10})
# E-GEOD-12187, Counter({'moderate chronic allograft nephropathy': 5, 'mild chronic allograft nephropathy': 3, 'severe chronic allograft nephropathy': 2})
# Counter({'peripheral blood': 10})
# E-GEOD-17538, Counter({'carcinoma': 9})
# Counter({'colon': 9})
# E-GEOD-17612, Counter({'schizophrenia': 5, 'normal': 4})
# Counter({'brain': 9})
# E-GEOD-21029, Counter({'chronic lymphocytic leukaemia': 9})
# Counter({'peripheral blood': 4, 'lymph node': 3, 'bone marrow': 2})
# E-GEOD-9169, Counter({'neuroblastoma': 8, 'neuroepithelioma': 1})
# Counter({'brain': 9})
# E-GEOD-13067, Counter({'colorectal adenocarcinoma': 9})
# Counter({'colon': 9})
# E-GEOD-8671, Counter({'colorectal adenoma': 6, 'normal': 3})
# Counter({'colon': 6, '  ': 3})
# E-GEOD-6575, Counter({'autism spectrum disorder': 8, 'normal': 1})
# Counter({'whole blood': 9})
# E-GEOD-6764, Counter({'HCV/hepatocellular carcinoma': 9})
# Counter({'liver': 9})
# E-GEOD-7553, Counter({'melanoma': 6, 'normal': 1, 'squamous cell carcinoma': 1, 'basal cell carcinoma': 1})
# Counter({'skin': 5, 'metastatic melanoma': 3, 'melanoma tumor': 1})
# E-GEOD-10890, Counter({'breast adenocarcinoma': 3, 'breast ductal carcinoma': 1, 'breast ductal adenocarcinoma': 1, 'breast cancer': 1, 'breast carcinoma': 1, 'breast metaplastic carcinoma': 1, 'breast fibrocystic disease': 1})
# Counter({'breast': 9})
# E-GEOD-20916, Counter({'carcinoma': 3, 'adenocarcinoma': 3, 'normal': 2})
# Counter({'colon': 8})
# E-MEXP-1243, Counter({'high-grade prostatic intraepithelial neoplasia': 6, 'prostate cancer': 1, 'benign prostatic hyperplasia': 1})
# Counter({'prostate': 8})
# E-GEOD-13319, Counter({'leiomyoma': 8})
# Counter({'uterus': 8})
# E-GEOD-12195, Counter({'diffuse large B-cell lymphoma': 8})
# Counter({'  ': 8})
# E-MEXP-1618, Counter({'normal': 8})
# Counter({'trans-iliacal bone': 8})
# E-GEOD-17170, Counter({'normal': 7})
# Counter({'  ': 7})
# E-GEOD-18497, Counter({'T-ALL': 4, 'common ALL': 2, 'pre B-ALL': 1})
# Counter({'  ': 7})
# E-GEOD-2677, Counter({'B-ALL': 5, 'T-ALL': 2})
# Counter({'peripheral blood': 7})
# E-GEOD-8121, Counter({'septic shock': 7})
# Counter({'whole blood': 7})
# E-MEXP-1216, Counter({'normal': 7})
# Counter({'  ': 6, 'bone': 1})
# E-GEOD-10792, Counter({'childhood B-cell precursor ALL': 7})
# Counter({'bone marrow': 6, 'peripheral blood': 1})
# E-GEOD-13351, Counter({'ALL': 7})
# Counter({'bone marrow or peripheral blood': 7})
# E-GEOD-15396, Counter({'colon carcinoma': 4, 'prostate carcinoma': 3})
# Counter({'colon': 4, 'prostate': 3})
# E-GEOD-16059, Counter({'normal': 5, 'chronic fatigue': 2})
# Counter({'peripheral blood': 7})
# E-GEOD-11906, Counter({'COPD': 4, 'normal': 3})
# Counter({'  ': 7})
# E-TABM-276, Counter({'breast carcinoma/cystic change': 5, 'breast carcinoma': 1, 'invasive ductal carcinoma': 1})
# Counter({'mammary gland': 7})
# E-GEOD-11877, Counter({'normal': 6, 'CNS affected': 1})
# Counter({'bone marrow': 6, 'peripheral blood': 1})
# E-MEXP-1512, Counter({'normal': 7})
# Counter({'bronchus': 7})
# E-GEOD-14062, Counter({'ALL without MLL rearrangement': 3, 'AML without MLL rearrangement': 2, 'AML with MLL rearrangement': 1, 'ALL with MLL rearrangement': 1})
# Counter({'  ': 7})
# E-GEOD-10245, Counter({'NSCLC': 6})
# Counter({'lung': 6})
# E-GEOD-10313, Counter({'normal': 6})
# Counter({'blood': 6})
# E-GEOD-13355, Counter({'psoriasis': 3, 'normal': 3})
# Counter({'skin': 6})
# E-GEOD-19804, Counter({'lung cancer': 6})
# Counter({'lung': 6})
# E-GEOD-14844, Counter({'normal': 6})
# Counter({'whole blood': 6})
# E-GEOD-14880, Counter({'neuroblastoma': 5, 'ganglioneuroblastoma': 1})
# Counter({'  ': 6})
# E-GEOD-10281, Counter({'breast cancer': 6})
# Counter({'breast': 6})
# E-GEOD-13837, Counter({'osteoarthritis': 5, 'rheumatoid arthritis': 1})
# Counter({'synovial membrane': 6})
# E-GEOD-19069, Counter({'peripheral T-cell lymphoma': 6})
# Counter({'  ': 6})
# E-GEOD-7586, Counter({'chronic malaria': 2, 'normal': 2, 'acute malaria': 1, 'previous malaria infection': 1})
# Counter({'placenta': 6})
# E-GEOD-8192, Counter({'cervical adenocarcinoma': 6})
# Counter({'cervix': 6})
# E-TABM-302, Counter({'moderately differentiated head and neck squamous cell carcinoma': 3, 'well differentiated head and neck squamous cell carcinoma': 2, 'poorly differentiated head and neck squamous cell carcinoma': 1})
# Counter({'hypopharynx': 3, 'oral cavity': 1, 'oropharynx': 1, 'tongue': 1})
# E-GEOD-12667, Counter({'lung adenocarcinoma': 6})
# Counter({'lung': 6})
# E-GEOD-23806, Counter({'glioblastoma': 4, 'glioma': 2})
# Counter({'brain': 6})
# E-MEXP-2236, Counter({'nonsyndromic sagittal synostosis': 2, 'Apert syndrome': 2, 'Soetre-Chotzen syndrome': 1, 'Muenke syndrome': 1})
# Counter({'skin': 6})
# E-GEOD-10063, Counter({'normal': 6})
# Counter({'oral cavity': 6})
# E-GEOD-12408, Counter({'normal': 3, 'Cornelia de Lange Syndrome': 3})
# Counter({'peripheral blood': 6})
# E-MEXP-2442, Counter({'fetal adenoma': 2, 'normal': 1, 'follicular adenoma': 1, 'follicular carcinoma': 1, 'nodular goiter': 1})
# Counter({'thyroid gland': 6})
# E-GEOD-10916, Counter({'melanoma': 6})
# Counter({'skin': 6})
# E-GEOD-16157, Counter({'lung fibrosarcoma': 6})
# Counter({'lung': 6})
# E-GEOD-13400, Counter({'normal': 3, 'esophageal adenocarcinoma': 2})
# Counter({'esophagus': 5})
# E-GEOD-14315, Counter({'lung cancer': 3, 'lung adenocarcinoma': 1, 'lung anaplastic carcinoma': 1})
# Counter({'lung': 5})
# E-GEOD-24422, Counter({'normal': 5})
# Counter({'bone marrow': 5})
# E-GEOD-5675, Counter({'pilocytic astrocytoma': 5})
# Counter({'brain': 5})
# E-GEOD-6521, Counter({'breast adenocarcinoma': 5})
# Counter({'breast': 5})
# E-GEOD-13139, Counter({'normal': 5})
# Counter({'aorta': 5})
# E-GEOD-11755, Counter({'meningococcal sepsis': 5})
# Counter({'peripheral blood': 5})
# E-GEOD-15235, Counter({'biliary atresia': 5})
# Counter({'liver': 5})
# E-GEOD-9826, Counter({'ovarian adenocarcinoma': 5})
# Counter({'ovary': 5})
# E-MEXP-2030, Counter({'normal': 5})
# Counter({'blood': 5})
# E-TABM-854, Counter({'invasive ductal carcinoma': 3, 'lobular carcinoma': 2})
# Counter({'breast': 5})
# E-GEOD-13576, Counter({'pediatric acute leukaemia': 5})
# Counter({'bone marrow': 5})
# E-GEOD-14386, Counter({'clinically isolated syndrome': 5})
# Counter({'peripheral blood': 5})
# E-GEOD-14618, Counter({'T-ALL': 5})
# Counter({'  ': 5})
# E-GEOD-9171, Counter({'glioma': 3, 'glioblastoma': 2})
# Counter({'brain': 5})
# E-MEXP-2599, Counter({'normal': 5})
# Counter({'kidney': 5})
# E-MEXP-935, Counter({'ovarian carcinoma': 5})
# Counter({'ovary': 5})
# E-GEOD-9988, Counter({'normal': 5})
# Counter({'  ': 5})
# E-GEOD-13904, Counter({'sepsis': 3, 'systemic inflammatory response syndrome': 1, 'septic shock': 1})
# Counter({'whole blood': 5})
# E-GEOD-18323, Counter({'normal': 5})
# Counter({'peripheral blood': 5})
# E-TABM-937, Counter({'multiple myeloma': 5})
# Counter({'bone marrow': 4, '  ': 1})
# E-GEOD-23501, Counter({'diffuse large B-cell lymphoma': 5})
# Counter({'lymph node': 5})
# E-GEOD-21138, Counter({'schizophrenia': 3, 'normal': 2})
# Counter({'prefrontal cortex': 5})
# E-GEOD-19293, Counter({'melanoma': 5})
# Counter({'extremity': 5})
# E-GEOD-25429, Counter({'serous epithelial ovarian cancer': 4, 'serous borderline ovarian cancer': 1})
# Counter({'ovary': 5})
# E-GEOD-7904, Counter({'normal': 3, 'basal-like breast cancer': 1, 'non-basal like breast cancer': 1})
# Counter({'breast': 4, 'breast organelle': 1})
# E-TABM-34, Counter({'normal': 5})
# Counter({'blood': 3, 'tonsil': 2})
# E-GEOD-21610, Counter({'dilated cardiomyopathy': 3, 'ischemic cardiomyopathy': 2})
# Counter({'myocardial tissue': 5})
# E-GEOD-4888, Counter({'normal': 5})
# Counter({'  ': 5})
# E-GEOD-6532, Counter({'breast cancer': 5})
# Counter({'  ': 5})
# E-GEOD-13548, Counter({'colorectal adenocarcinoma': 2, 'gastric cancer': 2})
# Counter({'colon': 2, 'stomach': 2})
# E-GEOD-18113, Counter({'normal': 4})
# Counter({'  ': 4})
# E-GEOD-20211, Counter({'chronic lymphocytic leukaemia': 4})
# Counter({'  ': 4})
# E-GEOD-25155, Counter({'normal': 4})
# Counter({'kidney': 4})
# E-GEOD-6013, Counter({'normal': 3, 'lung adenocarcinoma': 1})
# Counter({'lung/bronchus': 2, 'lung': 1, 'pleural fluid': 1})
# E-GEOD-6338, Counter({'normal': 2, 'peripheral T-cell lymphoma': 2})
# Counter({'peripheral blood or tonsil': 2, 'lymph node': 2})
# E-GEOD-9438, Counter({'meningioma': 4})
# Counter({'brain': 4})
# E-SGRP-3, Counter({'normal': 4})
# Counter({'umbilical vein': 4})
# E-GEOD-21912, Counter({'multiple myeloma': 4})
# Counter({'blood': 4})
# E-GEOD-10810, Counter({'breast cancer': 3, 'normal': 1})
# Counter({'breast': 4})
# E-GEOD-11761, Counter({'normal': 4})
# Counter({'peripheral blood': 4})
# E-GEOD-13896, Counter({'normal': 3, 'COPD': 1})
# Counter({'  ': 4})
# E-GEOD-19429, Counter({'myelodysplastic syndrome/refractory anemia with ringed sideroblasts': 2, 'myelodysplastic syndrome/refractory anemia': 1, 'myelodysplastic syndrome/refractory anemia with excess blasts': 1})
# Counter({'bone marrow': 4})
# E-GEOD-21687, Counter({'ependymoma': 4})
# Counter({'posterior fossa': 2, 'cerebrum': 2})
# E-GEOD-22356, Counter({'scleroderma without pulmonary hypertension': 2, 'normal': 1, 'scleroderma with pulmonary hypertension': 1})
# Counter({'peripheral blood': 4})
# E-GEOD-22563, Counter({'renal cell carcinoma': 3, 'renal clear cell carcinoma': 1})
# Counter({'kidney': 4})
# E-GEOD-26104, Counter({'multiple sclerosis': 4})
# Counter({'peripheral blood': 4})
# E-GEOD-9960, Counter({'sepsis': 4})
# Counter({'peripheral blood': 4})
# E-MEXP-2241, Counter({'normal': 4})
# Counter({'fibroblast': 4})
# E-MEXP-2460, Counter({'oral cavity squamous cell carcinoma': 2, 'larynx squamous cell carcinoma': 1, 'hypopharynx squamous cell carcinoma': 1})
# Counter({'blood': 4})
# E-TABM-898, Counter({'glioblastoma': 4})
# Counter({'brain': 4})
# E-GEOD-15471, Counter({'pancreatic cancer': 4})
# Counter({'pancreas': 4})
# E-GEOD-23764, Counter({'malignant melanoma': 4})
# Counter({'skin': 4})
# E-GEOD-9195, Counter({'breast cancer': 4})
# Counter({'breast': 4})
# E-MTAB-372, Counter({'myeloma': 4})
# Counter({'bone marrow': 4})
# E-TABM-868, Counter({'acute monocytic leukaemia': 4})
# Counter({'blood': 4})
# E-GEOD-15329, Counter({'B-cell lymphoma': 2, 'large cell lymphoma': 1, 'non-Hodgkins lymphoma': 1})
# Counter({'lymph node': 3, 'blood': 1})
# E-GEOD-21261, Counter({'acute myeloid leukaemia': 4})
# Counter({'peripheral blood': 4})
# E-TABM-127, Counter({'normal': 4})
# Counter({'bronchus': 4})
# E-GEOD-10445, Counter({'lung cancer': 4})
# Counter({'lung': 4})
# E-GEOD-15543, Counter({'normal': 4})
# Counter({'pancreas': 4})
# E-GEOD-16191, Counter({'unilateral cryptorchid': 3, 'contralateral testicular aplasia': 1})
# Counter({'testis': 4})
# E-GEOD-21654, Counter({'pancreatic cancer': 3, 'pancreatic adenocarcinoma': 1})
# Counter({'pancreas': 4})
# E-GEOD-22224, Counter({'kidney transplant recipient': 3, 'normal': 1})
# Counter({'peripheral blood': 4})
# E-GEOD-7788, Counter({'T-cell/histiocyte rich B-cell lymphoma': 3, "nodular lymphocyte predominant Hodgkin's lymphoma": 1})
# Counter({'lymph node': 4})
# E-GEOD-15434, Counter({'acute myeloid leukaemia': 4})
# Counter({'bone marrow': 4})
# E-GEOD-22541, Counter({'clear-cell renal cell carcinoma': 4})
# Counter({'  ': 4})
# E-GEOD-7152, Counter({'melanoma': 4})
# Counter({'skin': 4})
# E-GEOD-8167, Counter({'gastrointestinal stromal tumor': 4})
# Counter({'small intestine': 2, 'stomach': 2})
# E-GEOD-8332, Counter({'colon carcinoma': 2, 'pancreatic cancer': 1, 'melanoma': 1})
# Counter({'colon': 2, 'pancreas': 1, 'skin': 1})
# E-GEOD-19098, Counter({'normal': 4})
# Counter({'umbilical vein': 4})
# E-GEOD-19420, Counter({'type 2 diabetes mellitus': 3, 'pre-diabetes': 1})
# Counter({'skeletal muscle': 4})
# E-GEOD-20081, Counter({'cervical adenocarcinoma': 3, 'breast adenocarcinoma': 1})
# Counter({'cervix': 3, 'breast': 1})
# E-TABM-666, Counter({'pre-diabetes': 2, 'normal': 1, 'ICA (appearance of autoantibodies against islet cells)': 1})
# Counter({'whole blood': 4})
# E-GEOD-13987, Counter({'normal': 3, 'B-cell chronic lymphocytic leukaemia': 1})
# Counter({'peripheral blood': 4})
# E-GEOD-22229, Counter({'kidney transplant recipient': 2, 'normal': 2})
# Counter({'blood': 4})
# E-GEOD-12102, Counter({"Ewing's sarcoma": 4})
# Counter({'bone': 4})
# E-GEOD-23343, Counter({'normal': 2, 'type 2 diabetes': 1})
# Counter({'liver': 3})
# E-GEOD-15893, Counter({'breast adenocarcinoma': 3})
# Counter({'breast': 3})
# E-GEOD-16020, Counter({'autosomal dominant monocytopenia': 2, 'normal': 1})
# Counter({'peripheral blood': 3})
# E-GEOD-16028, Counter({'normal': 3})
# Counter({'peripheral blood': 3})
# E-GEOD-19067, Counter({'extranodal NK/T-cell lymphoma': 2, 'peripheral T-cell lymphoma': 1})
# Counter({'  ': 3})
# E-GEOD-6269, Counter({'pneumonia/empyema/S. Pneumoniae infection': 1, 'osteomyelitis/bacteremia/methicillin-resistant Staphylococcus aureus infection': 1, 'fever/influenza A infection': 1})
# Counter({'peripheral blood': 3})
# E-GEOD-9452, Counter({'ulcerative colitis with inflammation': 2, 'normal': 1})
# Counter({'descending colon': 2, 'sigmoideum': 1})
# E-MEXP-1171, Counter({'colon carcinoma': 3})
# Counter({'colon': 3})
# E-MEXP-1290, Counter({'normal': 3})
# Counter({'blood': 3})
# E-TABM-440, Counter({'normal': 3})
# Counter({'skin': 3})
# E-GEOD-4780, Counter({'meningioma': 3})
# Counter({'brain': 3})
# E-GEOD-7578, Counter({'desmoplastic cerebellar medulloblastoma': 3})
# Counter({'brain': 3})
# E-GEOD-10524, Counter({'diffuse large B-cell lymphoma': 2, 'testicular diffuse large B-cell lymphoma': 1})
# Counter({'  ': 3})
# E-GEOD-12452, Counter({'nasopharyngeal carcinoma': 2, 'normal': 1})
# Counter({'nasopharynx': 3})
# E-GEOD-14334, Counter({'normal': 3})
# Counter({'fetal lung': 3})
# E-GEOD-17624, Counter({'endometrial adenocarcinoma': 3})
# Counter({'uterus': 3})
# E-GEOD-18973, Counter({'hepatocellular carcinoma': 3})
# Counter({'liver': 3})
# E-GEOD-7216, Counter({'normal': 3})
# Counter({'skin': 3})
# E-GEOD-10315, Counter({'normal': 3})
# Counter({'bone marrow': 3})
# E-GEOD-11045, Counter({'normal': 3})
# Counter({'liver': 2, 'kidney': 1})
# E-GEOD-11499, Counter({'ulcerative colitis': 2, "Crohn's disease": 1})
# Counter({'peripheral blood': 3})
# E-GEOD-11952, Counter({'normal': 3})
# Counter({'  ': 3})
# E-GEOD-17251, Counter({'normal': 3})
# Counter({'liver': 3})
# E-GEOD-23402, Counter({'normal': 3})
# Counter({'  ': 3})
# E-GEOD-6364, Counter({'endometriosis': 3})
# Counter({'  ': 3})
# E-GEOD-8045, Counter({'lung adenocarcinoma': 3})
# Counter({'lung': 3})
# E-GEOD-9451, Counter({'normal': 3})
# Counter({'  ': 3})
# E-MEXP-1230, Counter({'normal': 3})
# Counter({'  ': 3})
# E-MEXP-858, Counter({'normal': 3})
# Counter({'bone marrow': 3})
# E-GEOD-15773, Counter({'obesity': 3})
# Counter({'  ': 3})
# E-GEOD-7757, Counter({'ALL with hyperdiploid karyotype': 2, 'T-ALL': 1})
# Counter({'bone marrow': 3})
# E-MEXP-964, Counter({'undifferentiated soft tissue sarcoma': 3})
# Counter({'  ': 3})
# E-GEOD-12098, Counter({'hip arthroplasty': 3})
# Counter({'bone marrow': 3})
# E-GEOD-12446, Counter({'prolapse': 3})
# Counter({'  ': 3})
# E-GEOD-12902, Counter({'mycosis fungoide (cutaneus T-cell lymphoma)': 3})
# Counter({'skin': 3})
# E-GEOD-13909, Counter({'normal': 2, 'Nijmegen breakage syndrome': 1})
# Counter({'peripheral blood': 2, 'spleen': 1})
# E-GEOD-13911, Counter({'gastric cancer': 3})
# Counter({'stomach': 3})
# E-GEOD-14461, Counter({'normal': 3})
# Counter({'lung/bronchus': 3})
# E-GEOD-17743, Counter({'gastrointestinal stromal tumor': 3})
# Counter({'  ': 3})
# E-GEOD-17938, Counter({'AMD': 3})
# Counter({'  ': 3})
# E-GEOD-22183, Counter({'gastric cancer': 2, 'gastric carcinoma': 1})
# Counter({'stomach': 3})
# E-GEOD-22282, Counter({'normal': 3})
# Counter({'  ': 3})
# E-GEOD-3202, Counter({'lung adenocarcinoma': 3})
# Counter({'lung': 3})
# E-MEXP-2280, Counter({'Progressive supranuclear palsy': 2, "Pick's disease": 1})
# Counter({'medial temporal lobe': 3})
# E-MEXP-2458, Counter({'hepatoma': 2, 'hepatocellular carcinoma': 1})
# Counter({'liver': 3})
# E-MEXP-2757, Counter({'thalassemia': 2, 'normal': 1})
# Counter({'bone marrow': 3})
# E-MEXP-921, Counter({'myeloma': 2, 'multiple myeloma': 1})
# Counter({'blood': 3})
# E-TABM-311, Counter({'adenoma': 2, 'adrenocortical tumor': 1})
# Counter({'adrenal gland': 3})
# E-GEOD-14827, Counter({'osteosarcoma': 3})
# Counter({'femur': 2, 'tibia': 1})
# E-GEOD-15947, Counter({'normal': 3})
# Counter({'prostate': 3})
# E-GEOD-21570, Counter({'non-invasive glioma': 2, 'highly invasive glioma': 1})
# Counter({'brain': 3})
# E-MEXP-2069, Counter({'normal': 3})
# Counter({'peripheral blood': 3})
# E-MEXP-2813, Counter({'normal': 3})
# Counter({'  ': 3})
# E-GEOD-16515, Counter({'pancreatic cancer': 3})
# Counter({'pancreas': 3})
# E-GEOD-12838, Counter({'normal': 3})
# Counter({'buffy coat': 2, 'blood': 1})
# E-GEOD-14858, Counter({'juvenile myelomonocytic leukaemia': 3})
# Counter({'bone marrow': 2, 'peripheral blood': 1})
# E-GEOD-14987, Counter({'breast fibrocystic disease': 3})
# Counter({'breast': 3})
# E-GEOD-17061, Counter({'AML(FAB-M0)': 3})
# Counter({'peripheral blood and bone marrow': 3})
# E-GEOD-18791, Counter({'normal': 3})
# Counter({'  ': 3})
# E-GEOD-18906, Counter({'normal': 3})
# Counter({'  ': 3})
# E-GEOD-24235, Counter({'normal': 3})
# Counter({'biceps brachii': 3})
# E-GEOD-5816, Counter({'NSCLC': 1, 'normal': 1, 'lung adenocarcinoma': 1})
# Counter({'lung': 2, 'bronchus': 1})
# E-GEOD-7392, Counter({'normal': 2, 'subclinical interstitial fibrosis': 1})
# Counter({'kidney allograft': 3})
# E-GEOD-7509, Counter({'normal': 3})
# Counter({'peripheral blood': 3})
# E-GEOD-8586, Counter({'normal': 2, 'bronchopulmonary dysplasia': 1})
# Counter({'umbilical cord': 3})
# E-GEOD-9649, Counter({'normal': 3})
# Counter({'breast': 3})
# E-MEXP-1883, Counter({'Sjogren syndrome': 3})
# Counter({'salivary gland': 3})
# E-MEXP-862, Counter({'chronic myeloid leukaemia': 3})
# Counter({'blood': 3})
# E-GEOD-11227, Counter({'renal disease': 3})
# Counter({'peripheral blood': 3})
# E-GEOD-13309, Counter({'lung anaplastic carcinoma': 2, 'lung adenocarcinoma': 1})
# Counter({'lung': 3})
# E-GEOD-23935, Counter({'glioblastoma': 3})
# Counter({'brain': 3})
# E-GEOD-26440, Counter({'septic shock': 3})
# Counter({'whole blood': 3})
# E-MEXP-1648, Counter({'normal': 3})
# Counter({'  ': 3})
# E-GEOD-11407, Counter({'breast adenocarcinoma': 3})
# Counter({'breast': 3})
# E-GEOD-14926, Counter({'normal': 3})
# Counter({'peripheral blood': 3})
# E-GEOD-18486, Counter({'ovarian adenocarcinoma': 3})
# Counter({'ovary': 3})
# E-GEOD-18811, Counter({'normal': 3})
# Counter({'retina': 2, '  ': 1})
# E-GEOD-22973, Counter({'pancreatic adenocarcinoma': 2, 'pancreatic cancer': 1})
# Counter({'pancreas': 3})
# E-GEOD-10311, Counter({'normal': 3})
# Counter({'trabecular bone': 3})
# E-GEOD-12764, Counter({'breast fibrocystic disease': 3})
# Counter({'breast': 3})
# E-GEOD-6885, Counter({'normal': 3})
# Counter({'breast': 3})
# E-MEXP-973, Counter({'normal': 3})
# Counter({'blood': 3})
# E-GEOD-19826, Counter({'gastric cancer': 2, 'normal': 1})
# Counter({'  ': 3})
# E-GEOD-8023, Counter({'normal': 3})
# Counter({'umbilical cord blood': 3})
# E-GEOD-9624, Counter({'normal': 2, 'obesity': 1})
# Counter({'  ': 3})
# E-GEOD-14383, Counter({'normal': 3})
# Counter({'lung/bronchus': 3})
# E-GEOD-2817, Counter({'diffuse glioma': 3})
# Counter({'brain': 3})
# E-GEOD-12720, Counter({'normal': 3})
# Counter({'liver': 3})
# E-GEOD-5264, Counter({'normal': 3})
# Counter({'bronchus': 3})
# E-GEOD-10021, Counter({'erythroleukaemia': 1, 'hepatocellular carcinoma': 1})
# Counter({'blood': 1, 'liver': 1})
# E-GEOD-10135, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-10961, Counter({'colorectal cancer': 2})
# Counter({'  ': 2})
# E-GEOD-11100, Counter({'glioblastoma': 2})
# Counter({'brain': 2})
# E-GEOD-11618, Counter({'colon carcinoma': 2})
# Counter({'colon': 2})
# E-GEOD-13564, Counter({'normal': 2})
# Counter({'dorsolateral prefrontal cortex': 2})
# E-GEOD-16357, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-18235, Counter({'normal': 2})
# Counter({'bronchus or trachea': 2})
# E-GEOD-18866, Counter({'chronic lymphocytic leukaemia': 2})
# Counter({'  ': 2})
# E-GEOD-20847, Counter({'normal': 2})
# Counter({'skin': 2})
# E-GEOD-24810, Counter({'normal': 2})
# Counter({'breast': 2})
# E-GEOD-25332, Counter({'endometrial cancer': 2})
# Counter({'uterus': 2})
# E-GEOD-5787, Counter({'cervical cancer': 2})
# Counter({'cervix': 2})
# E-GEOD-8581, Counter({'COPD/giant bullae': 1, 'carcinoid': 1})
# Counter({'lung': 2})
# E-MEXP-1828, Counter({'celiac': 2})
# Counter({'duodenum': 2})
# E-MEXP-421, Counter({'normal': 2})
# Counter({'kidney': 2})
# E-GEOD-10896, Counter({'diffuse histiocytic lymphoma': 2})
# Counter({'pleura': 2})
# E-GEOD-10591, Counter({'hepatocellular carcinoma': 2})
# Counter({'liver': 2})
# E-GEOD-13396, Counter({'normal': 2})
# Counter({'bronchus': 2})
# E-GEOD-16648, Counter({'pancreatic cancer': 1, 'osteosarcoma': 1})
# Counter({'pancreas': 1, 'bone': 1})
# E-GEOD-19777, Counter({'breast adenocarcinoma': 2})
# Counter({'breast': 2})
# E-GEOD-23640, Counter({'breast ductal carcinoma': 1, 'breast cancer': 1})
# Counter({'breast': 1, '  ': 1})
# E-GEOD-5563, Counter({'normal': 1, 'vulvar intraepithelial neoplasia': 1})
# Counter({'vulva': 2})
# E-GEOD-7011, Counter({'normal': 2})
# Counter({'umbilical cord blood': 2})
# E-GEOD-8665, Counter({'normal': 2})
# Counter({'bone marrow': 2})
# E-GEOD-8742, Counter({'breast adenocarcinoma': 1, 'colon adenocarcinoma': 1})
# Counter({'breast': 1, 'colon': 1})
# E-GEOD-9089, Counter({'normal': 2})
# Counter({'prostate': 1, '  ': 1})
# E-GEOD-9647, Counter({'normal': 2})
# Counter({'umbilical vein': 2})
# E-GEOD-9768, Counter({"Barret's syndrome": 2})
# Counter({'  ': 2})
# E-GEOD-10715, Counter({'colorectal cancer': 2})
# Counter({'peripheral blood': 2})
# E-GEOD-11791, Counter({'breast adenocarcinoma': 2})
# Counter({'breast': 2})
# E-GEOD-12488, Counter({'T-LGL lymphocytosis': 1, 'normal': 1})
# Counter({'  ': 2})
# E-GEOD-14108, Counter({'lung cancer': 2})
# Counter({'  ': 2})
# E-GEOD-17400, Counter({'lung adenocarcinoma': 2})
# Counter({'lung': 2})
# E-GEOD-18625, Counter({'colon adenocarcinoma': 2})
# Counter({'colon': 2})
# E-GEOD-19234, Counter({'melanoma': 2})
# Counter({'skin': 2})
# E-GEOD-20033, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-22544, Counter({'infiltrating ductal carcinoma': 2})
# Counter({'breast': 2})
# E-GEOD-24473, Counter({'breast ductal adenocarcinoma': 2})
# Counter({'breast': 2})
# E-GEOD-25550, Counter({'MALT lymphoma': 1, 'normal': 1})
# Counter({'MALT lymphoma': 1, 'spleen': 1})
# E-GEOD-6004, Counter({'normal': 1, 'papillary thyroid cancer': 1})
# Counter({'thyroid': 2})
# E-GEOD-8597, Counter({'breast adenocarcinoma': 2})
# Counter({'breast': 2})
# E-GEOD-8702, Counter({'prostate adenocarcinoma': 2})
# Counter({'prostate': 2})
# E-GEOD-9264, Counter({'normal': 2})
# Counter({'kidney': 2})
# E-GEOD-9419, Counter({'normal': 2})
# Counter({'vastus lateralis': 2})
# E-GEOD-9576, Counter({'normal': 1, 'midgut carcinoid': 1})
# Counter({'ileum': 1, '  ': 1})
# E-MEXP-1901, Counter({'rectal adenocarcinoma': 2})
# Counter({'rectum': 2})
# E-MEXP-2285, Counter({'normal': 2})
# Counter({'foreskin': 2})
# E-TABM-767, Counter({'NSCLC': 1, 'prostate carcinoma': 1})
# Counter({'lung': 1, 'prostate': 1})
# E-GEOD-14378, Counter({'CCRCC': 2})
# Counter({'  ': 2})
# E-GEOD-15499, Counter({'normal': 2})
# Counter({'umbilical vein': 2})
# E-GEOD-16193, Counter({'acute monocytic leukaemia': 2})
# Counter({'blood': 2})
# E-GEOD-16728, Counter({'normal': 2})
# Counter({'peripheral blood': 2})
# E-GEOD-18913, Counter({'normal': 2})
# Counter({'umbilical vein': 2})
# E-GEOD-20058, Counter({'gastric adenocarcinoma': 2})
# Counter({'stomach': 2})
# E-GEOD-22152, Counter({'acute lymphoblastic leukaemia': 2})
# Counter({'blood': 2})
# E-GEOD-22968, Counter({'melanoma': 2})
# Counter({'skin': 2})
# E-GEOD-23980, Counter({'soft tissue sarcoma': 2})
# Counter({'  ': 2})
# E-GEOD-25145, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-3325, Counter({'metastatic prostate cancer': 2})
# Counter({'prostate gland': 2})
# E-GEOD-4107, Counter({'colorectal cancer': 1, 'normal': 1})
# Counter({'  ': 2})
# E-GEOD-7036, Counter({'normal': 1, 'bipolar disorder': 1})
# Counter({'  ': 2})
# E-MEXP-903, Counter({'glioblastoma': 2})
# Counter({'brain': 2})
# E-GEOD-14537, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-10139, Counter({'chronic lymphocytic leukaemia': 2})
# Counter({'  ': 2})
# E-GEOD-10592, Counter({'normal': 2})
# Counter({'well-differentiated bronchial airway': 2})
# E-GEOD-11428, Counter({'prostate cancer': 2})
# Counter({'prostate': 2})
# E-GEOD-12773, Counter({'atopy': 2})
# Counter({'peripheral blood': 2})
# E-GEOD-13985, Counter({'normal': 2})
# Counter({'blood': 2})
# E-GEOD-16238, Counter({'lung squamous cell carcinoma': 1, 'erythroleukaemia': 1})
# Counter({'lung': 1, 'bone marrow': 1})
# E-GEOD-18105, Counter({'carcinoma': 2})
# Counter({'colon': 2})
# E-GEOD-20677, Counter({'normal': 2})
# Counter({'peripheral blood': 2})
# E-GEOD-21589, Counter({'HIV-1': 2})
# Counter({'inguinal lymph node': 2})
# E-GEOD-6207, Counter({'hepatocellular carcinoma': 2})
# Counter({'liver': 2})
# E-GEOD-6791, Counter({'cervical cancer': 1, 'head and neck cancer': 1})
# Counter({'cervix': 1, 'oropharynx': 1})
# E-GEOD-7890, Counter({'normal': 2})
# Counter({'skin': 2})
# E-GEOD-8823, Counter({'normal': 2})
# Counter({'alveolus': 2})
# E-GEOD-11324, Counter({'breast adenocarcinoma': 2})
# Counter({'breast': 2})
# E-GEOD-12460, Counter({'neuroblastoma': 1, 'ganglioneuroblastoma': 1})
# Counter({'  ': 2})
# E-GEOD-13491, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-13670, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-16455, Counter({'chronic lymphocytic leukaemia': 1, 'conventional mantle cell lymphoma': 1})
# Counter({'peripheral blood': 2})
# E-GEOD-16524, Counter({'normal': 2})
# Counter({'skin': 2})
# E-GEOD-16797, Counter({'Kawasaki disease': 2})
# Counter({'peripheral blood': 2})
# E-GEOD-17906, Counter({'normal': 1, 'prostate cancer': 1})
# Counter({'prostate': 2})
# E-GEOD-5679, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-7127, Counter({'melanoma': 2})
# Counter({'skin': 2})
# E-GEOD-7161, Counter({'colon carcinoma': 2})
# Counter({'colon': 2})
# E-GEOD-8596, Counter({"Ewing's sarcoma": 2})
# Counter({'  ': 1, 'biceps': 1})
# E-GEOD-8977, Counter({'normal': 2})
# Counter({'mammary gland': 2})
# E-GEOD-9212, Counter({'normal': 2})
# Counter({'bronchus': 2})
# E-TABM-1088, Counter({'myeloma': 2})
# Counter({'-': 1, 'blood': 1})
# E-GEOD-7696, Counter({'glioblastoma multiforme': 2})
# Counter({'brain': 2})
# E-GEOD-10070, Counter({'breast fibrocystic disease': 2})
# Counter({'breast': 2})
# E-GEOD-11103, Counter({'acute monocytic leukaemia': 1, 'mixture': 1})
# Counter({'blood': 2})
# E-GEOD-12265, Counter({'normal': 2})
# Counter({'bone marrow': 2})
# E-GEOD-15083, Counter({'oligoarticular juvenile idiopathic arthritis': 2})
# Counter({'synovial fluid': 2})
# E-GEOD-19963, Counter({'familial hyperplastic polyposis': 2})
# Counter({'  ': 2})
# E-GEOD-22501, Counter({'normal': 2})
# Counter({'peripheral blood': 1, 'umbilical cord blood': 1})
# E-MEXP-561, Counter({'normal': 1, "Kaposi's sarcoma": 1})
# Counter({'skin': 2})
# E-GEOD-17306, Counter({'multiple myeloma': 2})
# Counter({'  ': 2})
# E-GEOD-4237, Counter({'pituitary tumor': 2})
# Counter({'pituitary gland': 2})
# E-GEOD-10700, Counter({'normal': 2})
# Counter({'bronchus': 2})
# E-GEOD-11886, Counter({'normal': 2})
# Counter({'peripheral blood': 2})
# E-GEOD-20950, Counter({'obesity': 2})
# Counter({'  ': 2})
# E-GEOD-21541, Counter({'breast ductal adenocarcinoma': 2})
# Counter({'breast': 2})
# E-GEOD-23583, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-23631, Counter({'renal cancer': 2})
# Counter({'  ': 2})
# E-GEOD-23878, Counter({'colorectal carcinoma': 2})
# Counter({'colon': 2})
# E-GEOD-6819, Counter({'cervical adenocarcinoma': 2})
# Counter({'cervix': 2})
# E-GEOD-7345, Counter({'normal': 2})
# Counter({'blood': 2})
# E-GEOD-7621, Counter({"Parkinson's disease": 2})
# Counter({'substantia nigra': 2})
# E-GEOD-8588, Counter({'adrenocortical carcinoma': 2})
# Counter({'adrenal gland': 2})
# E-GEOD-8762, Counter({"Huntington's disease": 2})
# Counter({'peripheral blood': 2})
# E-MEXP-1192, Counter({'normal': 2})
# Counter({'  ': 2})
# E-MEXP-1337, Counter({'normal': 2})
# Counter({'intestine': 2})
# E-GEOD-11839, Counter({'stress incontinence': 1, 'interstitial cystitis': 1})
# Counter({'bladder': 2})
# E-GEOD-15271, Counter({'inflamed tonsil': 2})
# Counter({'  ': 2})
# E-GEOD-18696, Counter({'normal': 2})
# Counter({'entorhinal cortex': 2})
# E-GEOD-20948, Counter({'hepatocellular carcinoma': 2})
# Counter({'liver': 2})
# E-GEOD-22035, Counter({'primary unilateral non-metastatic breast cancer': 2})
# Counter({'breast': 2})
# E-GEOD-22842, Counter({'osteosarcoma': 2})
# Counter({'bone': 2})
# E-GEOD-6281, Counter({'nickel allergy': 2})
# Counter({'skin': 2})
# E-GEOD-7708, Counter({'prostate adenocarcinoma': 2})
# Counter({'prostate': 2})
# E-MEXP-1372, Counter({'colon adenocarcinoma': 2})
# Counter({'colon': 2})
# E-MEXP-2146, Counter({'normal': 2})
# Counter({'cord blood': 2})
# E-GEOD-4773, Counter({'neuroblastoma (Ewing sarcoma)': 2})
# Counter({'brain': 2})
# E-GEOD-12504, Counter({'vessel ischemic heart disease': 2})
# Counter({'heart': 2})
# E-GEOD-12917, Counter({'normal': 2})
# Counter({'breast': 2})
# E-GEOD-16870, Counter({'cervical adenocarcinoma': 2})
# Counter({'cervix': 2})
# E-GEOD-5372, Counter({'normal': 2})
# Counter({'bronchus': 2})
# E-GEOD-5741, Counter({'normal': 2})
# Counter({'retina': 2})
# E-GEOD-7808, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-14519, Counter({'myeloma': 2})
# Counter({'blood': 2})
# E-GEOD-17718, Counter({'ATL': 1, 'normal': 1})
# Counter({'  ': 2})
# E-GEOD-19667, Counter({'normal': 2})
# Counter({'small airways': 2})
# E-GEOD-19902, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-21222, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-6088, Counter({'normal': 2})
# Counter({'peripheral blood': 2})
# E-MEXP-2572, Counter({'normal': 2})
# Counter({'  ': 2})
# E-MEXP-2645, Counter({'tongue squamous cell carcinoma': 2})
# Counter({'tongue': 2})
# E-TABM-740, Counter({'obesity': 2})
# Counter({'peripheral blood': 2})
# E-GEOD-12355, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-13433, Counter({'alveolar soft-part sarcoma': 2})
# Counter({'  ': 2})
# E-GEOD-13712, Counter({'normal': 2})
# Counter({'umbilical vein': 2})
# E-GEOD-17482, Counter({'prostate cancer': 1, 'prostate carcinoma': 1})
# Counter({'prostate': 2})
# E-GEOD-20559, Counter({'differentiated liposarcoma': 1, 'pleomorphic liposarcoma': 1})
# Counter({'fat': 2})
# E-GEOD-24147, Counter({'diffuse large B-cell lymphoma': 1, 'acute promyelocytic leukaemia': 1})
# Counter({'blood': 2})
# E-GEOD-8837, Counter({'normal': 2})
# Counter({'  ': 2})
# E-MEXP-456, Counter({'hepatocellular carcinoma': 2})
# Counter({'liver': 2})
# E-TABM-702, Counter({'normal': 1, 'nodal peripheral T-cell lymphoma': 1})
# Counter({'  ': 1, 'lymph node': 1})
# E-GEOD-12710, Counter({'normal': 2})
# Counter({'peripheral blood': 2})
# E-GEOD-18047, Counter({'leukaemia': 1, 'myeloma': 1})
# Counter({'pericardial effusion': 1, 'bone marrow': 1})
# E-GEOD-25458, Counter({'endometrial adenocarcinoma': 2})
# Counter({'uterus': 2})
# E-GEOD-2842, Counter({'acute lymphoblastic leukaemia': 2})
# Counter({'blood': 2})
# E-GEOD-5993, Counter({'cervical carcinoma': 2})
# Counter({'cervix': 2})
# E-MEXP-1546, Counter({'normal': 2})
# Counter({'umbilical cord': 2})
# E-MEXP-2034, Counter({'benign prostatic hyperplasia': 2})
# Counter({'prostate': 2})
# E-GEOD-22459, Counter({'IFTA': 1, 'normal': 1})
# Counter({'kidney allograft': 2})
# E-GEOD-10714, Counter({'hyperplastic polyp': 2})
# Counter({'colon': 2})
# E-GEOD-15323, Counter({'rhabdomyosarcoma': 2})
# Counter({'connective tissue': 2})
# E-GEOD-15372, Counter({'ovarian carcinoma': 1, 'ovarian adenocarcinoma': 1})
# Counter({'ovary': 2})
# E-GEOD-15481, Counter({'breast adenocarcinoma': 2})
# Counter({'breast': 2})
# E-GEOD-20484, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-7967, Counter({'normal': 2})
# Counter({'umbilical cord blood': 2})
# E-GEOD-5809, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-10233, Counter({'acute monocytic leukaemia': 2})
# Counter({'blood': 2})
# E-GEOD-19713, Counter({'prostate cancer': 2})
# Counter({'prostate': 2})
# E-MIMR-644, Counter({'osteosarcoma': 2})
# Counter({'femoral condyle and tibial plateau': 2})
# E-TABM-20, Counter({'normal': 2})
# Counter({'frontal cortex/hippocampus': 1, 'frontal cortex': 1})
# E-GEOD-13205, Counter({'normal': 2})
# Counter({'vastus lateralis': 2})
# E-GEOD-13487, Counter({'melanoma': 2})
# Counter({'skin': 2})
# E-GEOD-13811, Counter({'chronic lymphocytic leukaemia': 2})
# Counter({'  ': 2})
# E-GEOD-14924, Counter({'acute myeloid leukaemia': 2})
# Counter({'peripheral blood': 2})
# E-GEOD-19330, Counter({'normal': 2})
# Counter({'  ': 2})
# E-GEOD-19578, Counter({'pediatric-high grade glioma/anaplastic astrocytoma': 2})
# Counter({'brain': 2})
# E-GEOD-22336, Counter({'pancreatic cancer': 2})
# Counter({'pancreas': 2})
# E-GEOD-7554, Counter({'normal': 2})
# Counter({'kidney': 2})
# E-GEOD-13314, Counter({'pulmonary MALT lymphoma': 2})
# Counter({'  ': 2})
# E-GEOD-17347, Counter({'squamous cell carcinoma': 1, 'lung adenocarcinoma': 1})
# Counter({'-': 1, 'lung': 1})
# E-GEOD-18565, Counter({'normal': 2})
# Counter({'blood': 2})
# E-GEOD-8527, Counter({'pharyngeal carcinoma': 2})
# Counter({'nasal pharynx': 2})
# E-GEOD-9762, Counter({'normal': 1})
# Counter({'skin': 1})
# E-GEOD-14773, Counter({'colon adenocarcinoma': 1})
# Counter({'colon': 1})
# E-GEOD-16363, Counter({'normal': 1})
# Counter({'lymph node': 1})
# E-GEOD-19625, Counter({'normal': 1})
# Counter({'blood': 1})
# E-GEOD-19728, Counter({'diffusely infiltrating astrocytic glioma': 1})
# Counter({'brain': 1})
# E-GEOD-6767, Counter({'cervical adenocarcinoma': 1})
# Counter({'cervix': 1})
# E-GEOD-7247, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-7835, Counter({'glioblastoma': 1})
# Counter({'brain': 1})
# GSM248743.CEL, Counter({'hepatitis C virus-induced hepatocellular carcinoma': 1})
# Counter({'liver': 1})
# E-MEXP-2612, Counter({"Graves' disease": 1})
# Counter({'thyroid gland': 1})
# E-MTAB-93, Counter({'cervical adenocarcinoma': 1})
# Counter({'cervix': 1})
# E-GEOD-12205, Counter({'normal': 1})
# Counter({'lung': 1})
# E-GEOD-12734, Counter({'chronic lymphocytic leukaemia': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-17763, Counter({'lepromatous leprosy': 1})
# Counter({'skin': 1})
# E-GEOD-19639, Counter({'breast adenocarcinoma': 1})
# Counter({'breast': 1})
# E-GEOD-20854, Counter({'endometrial adenocarcinoma': 1})
# Counter({'uterus': 1})
# E-GEOD-21092, Counter({'normal': 1})
# Counter({'kidney': 1})
# E-GEOD-22256, Counter({'renal adenocarcinoma': 1})
# Counter({'kidney': 1})
# E-GEOD-22490, Counter({'normal': 1})
# Counter({'placenta': 1})
# E-GEOD-22589, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-26828, Counter({'normal': 1})
# Counter({'urothelium': 1})
# E-GEOD-5823, Counter({'breast adenocarcinoma': 1})
# Counter({'breast': 1})
# E-GEOD-6460, Counter({'normal': 1})
# Counter({'bone marrow': 1})
# E-GEOD-6878, Counter({'hepatocellular carcinoma': 1})
# Counter({'liver': 1})
# E-GEOD-8668, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-TABM-601, Counter({'breast adenocarcinoma': 1})
# Counter({'breast': 1})
# E-GEOD-10316, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-12963, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-13059, Counter({'colorectal adenocarcinoma': 1})
# Counter({'colon': 1})
# E-GEOD-16226, Counter({'normal': 1})
# Counter({'foot': 1})
# E-GEOD-17480, Counter({'chronic myeloid leukaemia': 1})
# Counter({'  ': 1})
# E-GEOD-17920, Counter({"chronic Hodgkin's lymphoma": 1})
# Counter({'lymph node': 1})
# E-GEOD-18476, Counter({'diffuse histiocytic lymphoma': 1})
# Counter({'pleura': 1})
# E-GEOD-18842, Counter({'non-small cell lung cancer': 1})
# Counter({'lung': 1})
# E-GEOD-6054, Counter({'familial hypercholesterolemia': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-8049, Counter({'glioblastoma': 1})
# Counter({'brain': 1})
# E-GEOD-8687, Counter({'cutaneous T-cell lymphoma': 1})
# Counter({'  ': 1})
# E-GEOD-9692, Counter({'septic shock': 1})
# Counter({'peripheral blood': 1})
# E-MEXP-1032, Counter({'cervical adenocarcinoma': 1})
# Counter({'cervix': 1})
# E-MEXP-1140, Counter({'organ donor': 1})
# Counter({'islet of Langerhans': 1})
# E-MEXP-2359, Counter({'normal': 1})
# Counter({'embryo': 1})
# E-MEXP-2795, Counter({'normal': 1})
# Counter({'bronchus': 1})
# E-TABM-782, Counter({'acute monocytic leukaemia': 1})
# Counter({'blood': 1})
# E-GEOD-10927, Counter({'adrenocortical carcinoma': 1})
# Counter({'adrenal gland': 1})
# E-GEOD-11367, Counter({'normal': 1})
# Counter({'aorta': 1})
# E-GEOD-11956, Counter({'hepatocellular carcinoma': 1})
# Counter({'liver': 1})
# E-GEOD-12846, Counter({'normal': 1})
# Counter({'foreskin': 1})
# E-GEOD-13637, Counter({'normal': 1})
# Counter({'umbilical vein': 1})
# E-GEOD-14231, Counter({'malignant testicular teratoma': 1})
# Counter({'testis': 1})
# E-GEOD-14390, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-16161, Counter({'atopic dermatitis': 1})
# Counter({'skin': 1})
# E-GEOD-17551, Counter({'melanoma': 1})
# Counter({'  ': 1})
# E-GEOD-23183, Counter({'HIV-1': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-25407, Counter({'breast cancer': 1})
# Counter({'  ': 1})
# E-GEOD-6451, Counter({'neuroblastoma': 1})
# Counter({'brain': 1})
# E-GEOD-7476, Counter({'bladder cancer': 1})
# Counter({'bladder': 1})
# GSM187769.CEL, Counter({'c-ALL': 1})
# Counter({'bone marrow': 1})
# E-MEXP-2160, Counter({'normal': 1})
# Counter({'uterus': 1})
# E-TABM-118, Counter({"Crohn's disease": 1})
# Counter({'descending colon': 1})
# E-TABM-424, Counter({'gastric cancer': 1})
# Counter({'stomach': 1})
# E-GEOD-2864, Counter({'neuroblastoma': 1})
# Counter({'brain': 1})
# E-GEOD-14973, Counter({'chronic lymphocytic leukaemia': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-16194, Counter({'lung adenocarcinoma': 1})
# Counter({'lung': 1})
# E-GEOD-16354, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-16837, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-17353, Counter({'normal': 1})
# Counter({'esophagus': 1})
# E-GEOD-19315, Counter({'acute monocytic leukaemia': 1})
# Counter({'blood': 1})
# E-GEOD-20285, Counter({'breast fibrocystic disease': 1})
# Counter({'breast': 1})
# E-GEOD-2125, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-22167, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-23618, Counter({'normal': 1})
# Counter({'skin': 1})
# E-GEOD-26966, Counter({'gonadotrope tumor': 1})
# Counter({'pituitary gland': 1})
# E-GEOD-7177, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-7454, Counter({'osteosarcoma': 1})
# Counter({'bone': 1})
# E-GEOD-9865, Counter({'normal': 1})
# Counter({'  ': 1})
# E-MEXP-1507, Counter({'glioblastoma with EGFR amplification': 1})
# Counter({'brain': 1})
# E-MEXP-1599, Counter({'lung adenocarcinoma': 1})
# Counter({'lung': 1})
# E-MEXP-2213, Counter({'erythroleukaemia': 1})
# Counter({'blood': 1})
# Sample 6895:biotin, Counter({'normal': 1})
# Counter({'  ': 1})
# E-TABM-1020, Counter({'acute myeloid leukaemia': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-10650, Counter({'colon carcinoma': 1})
# Counter({'colon': 1})
# E-GEOD-12326, Counter({'acute myeloid leukaemia': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-13041, Counter({'primary glioblastoma': 1})
# Counter({'brain': 1})
# E-GEOD-13210, Counter({'Burkitt lymphoma': 1})
# Counter({'blood': 1})
# E-GEOD-18947, Counter({'osteosarcoma': 1})
# Counter({'bone': 1})
# E-GEOD-20272, Counter({'ovarian cancer': 1})
# Counter({'ovary': 1})
# E-GEOD-20508, Counter({'acute monocytic leukaemia': 1})
# Counter({'blood': 1})
# E-GEOD-21483, Counter({'head and neck cancer': 1})
# Counter({'head and neck': 1})
# E-GEOD-23687, Counter({'juvenile idiopathic arthritis': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-9150, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-9656, Counter({'Waldenstr\x9ams macroglobulinemia': 1})
# Counter({'  ': 1})
# JFT-E6E7260505.CEL, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-10847, Counter({'NSCLC': 1})
# Counter({'lung': 1})
# E-GEOD-16219, Counter({'mycosis fungoides': 1})
# Counter({'blood': 1})
# E-GEOD-18521, Counter({'ovarian adenocarcinoma': 1})
# Counter({'ovary': 1})
# E-GEOD-21550, Counter({'diffuse histiocytic lymphoma': 1})
# Counter({'pleura': 1})
# E-GEOD-23984, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-24170, Counter({'osteosarcoma': 1})
# Counter({'bone': 1})
# E-GEOD-26787, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-27187, Counter({'acute myeloid leukaemia': 1})
# Counter({'bone marrow': 1})
# E-GEOD-7845, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-9101, Counter({'acute monocytic leukaemia': 1})
# Counter({'blood': 1})
# E-MEXP-2218, Counter({'breast adenocarcinoma': 1})
# Counter({'breast': 1})
# E-TABM-759, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-10746, Counter({'acute myeloid leukaemia': 1})
# Counter({'oral cavity': 1})
# E-GEOD-10960, Counter({'cervical adenocarcinoma': 1})
# Counter({'cervix': 1})
# E-GEOD-11783, Counter({'normal': 1})
# Counter({'bladder': 1})
# E-GEOD-11881, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-13787, Counter({'her2+ breast cancer': 1})
# Counter({'breast': 1})
# E-GEOD-14596, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-25436, Counter({'melanoma': 1})
# Counter({'skin': 1})
# E-GEOD-27160, Counter({'normal': 1})
# Counter({'umbilical vein': 1})
# E-GEOD-6489, Counter({'normal': 1})
# Counter({'lung': 1})
# E-GEOD-6833, Counter({'melanoma': 1})
# Counter({'skin': 1})
# GSM187739.CEL, Counter({'c-ALL': 1})
# Counter({'bone marrow': 1})
# E-GEOD-8289, Counter({'normal': 1})
# Counter({'kidney': 1})
# E-GEOD-8658, Counter({'normal': 1})
# Counter({'  ': 1})
# E-MEXP-1985, Counter({'breast adenocarcinoma': 1})
# Counter({'breast': 1})
# E-MEXP-2573, Counter({'erythroleukaemia': 1})
# Counter({'blood': 1})
# E-GEOD-10026, Counter({'Burkitt lymphoma': 1})
# Counter({'  ': 1})
# E-GEOD-11418, Counter({'normal': 1})
# Counter({'dermis': 1})
# E-GEOD-11506, Counter({'breast adenocarcinoma': 1})
# Counter({'breast': 1})
# E-GEOD-12264, Counter({'normal': 1})
# Counter({'trabecular bone': 1})
# E-GEOD-12992, Counter({'medulloblastoma': 1})
# Counter({'brain': 1})
# E-GEOD-13818, Counter({'renal adenocarcinoma': 1})
# Counter({'kidney': 1})
# E-GEOD-14302, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-14491, Counter({'breast adenocarcinoma': 1})
# Counter({'breast': 1})
# E-GEOD-15090, Counter({'facioscapulohumeral muscular dystrophy': 1})
# Counter({'deltoid': 1})
# E-GEOD-15913, Counter({'chronic lymphocytic leukaemia': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-15918, Counter({'adrenocortical carcinoma': 1})
# Counter({'adrenal gland': 1})
# E-GEOD-16155, Counter({'ependymoma': 1})
# Counter({'brain': 1})
# E-GEOD-16538, Counter({'normal': 1})
# Counter({'lung': 1})
# E-GEOD-20540, Counter({'myeloma': 1})
# Counter({'blood': 1})
# E-GEOD-20745, Counter({'normal': 1})
# Counter({'umbilical vein': 1})
# E-GEOD-22259, Counter({'cervical adenocarcinoma': 1})
# Counter({'cervix': 1})
# E-MEXP-2345, Counter({'normal': 1})
# Counter({'  ': 1})
# E-MEXP-2990, Counter({'normal': 1})
# Counter({'  ': 1})
# E-TABM-783, Counter({'angioimmunoblastic T-cell lymphoma': 1})
# Counter({'lymph node': 1})
# E-GEOD-6276, Counter({'normal': 1})
# Counter({'kidney': 1})
# E-GEOD-10739, Counter({'acute monocytic leukaemia': 1})
# Counter({'blood': 1})
# E-GEOD-12267, Counter({'normal': 1})
# Counter({'bone marrow': 1})
# E-GEOD-14340, Counter({'normal': 1})
# Counter({'trunk neural crest': 1})
# E-GEOD-15101, Counter({'normal': 1})
# Counter({'forearm epidermis': 1})
# E-GEOD-18877, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-19449, Counter({'liposarcoma': 1})
# Counter({'  ': 1})
# GSM187716.CEL, Counter({'c-ALL': 1})
# Counter({'bone marrow': 1})
# GSM187755.CEL, Counter({'c-ALL': 1})
# Counter({'bone marrow': 1})
# E-GEOD-7964, Counter({'NSCLC': 1})
# Counter({'lung': 1})
# E-MEXP-1586, Counter({'normal': 1})
# Counter({'blood': 1})
# E-MEXP-882, Counter({'infiltrating ductal carcinoma': 1})
# Counter({'mammary gland': 1})
# E-GEOD-10979, Counter({'HeLa cell contamination': 1})
# Counter({'amnion': 1})
# E-GEOD-11092, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-13506, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-14538, Counter({'colon adenocarcinoma': 1})
# Counter({'colon': 1})
# E-GEOD-14642, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-14842, Counter({'diarrhea-irritable bowel syndrome': 1})
# Counter({'jejunal mucosa': 1})
# E-GEOD-14956, Counter({'acyanotic Tetralogy of Fallot': 1})
# Counter({'heart right ventricle': 1})
# E-GEOD-15043, Counter({'breast cancer': 1})
# Counter({'breast': 1})
# E-GEOD-16070, Counter({'breast adenocarcinoma': 1})
# Counter({'breast': 1})
# E-GEOD-20641, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-21930, Counter({'colon adenocarcinoma': 1})
# Counter({'colon': 1})
# E-GEOD-22061, Counter({'colon carcinoma': 1})
# Counter({'colon': 1})
# E-GEOD-22483, Counter({'prostate adenocarcinoma': 1})
# Counter({'prostate': 1})
# E-GEOD-24362, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-4567, Counter({'normal': 1})
# Counter({'pulmonary artery': 1})
# E-GEOD-7486, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-7624, Counter({'schizophrenia': 1})
# Counter({'  ': 1})
# E-GEOD-8646, Counter({'NSCLC': 1})
# Counter({'lung': 1})
# E-GEOD-9832, Counter({'normal': 1})
# Counter({'lung': 1})
# E-GEOD-9951, Counter({'normal': 1})
# Counter({'prostate': 1})
# E-GEOD-9984, Counter({'normal': 1})
# Counter({'placenta': 1})
# E-GEOD-10463, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-12251, Counter({'ulcerative colitis': 1})
# Counter({'colon': 1})
# E-GEOD-13906, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-14429, Counter({'normal': 1})
# Counter({'kidney': 1})
# E-GEOD-14897, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-16085, Counter({'erythroleukaemia': 1})
# Counter({'blood': 1})
# E-GEOD-16615, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-18681, Counter({'ovarian cancer': 1})
# Counter({'  ': 1})
# E-GEOD-19128, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-25090, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-4183, Counter({'colon adenoma': 1})
# Counter({'colon': 1})
# E-GEOD-5040, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-6283, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-7181, Counter({'glioblastoma': 1})
# Counter({'brain': 1})
# E-GEOD-7500, Counter({'malignant pluripotent embryonal carcinoma': 1})
# Counter({'embryonic testis': 1})
# E-GEOD-8442, Counter({'adrenocortical carcinoma': 1})
# Counter({'adrenal gland': 1})
# E-GEOD-8608, Counter({'normal': 1})
# Counter({'  ': 1})
# E-MEXP-1178, Counter({'normal': 1})
# Counter({'kidney': 1})
# E-MEXP-2340, Counter({'neuroblastoma': 1})
# Counter({'brain': 1})
# E-GEOD-10006, Counter({'COPD': 1})
# Counter({'  ': 1})
# E-GEOD-11330, Counter({'breast adenocarcinoma': 1})
# Counter({'breast': 1})
# E-GEOD-12709, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-14507, Counter({'lung adenocarcinoma': 1})
# Counter({'lung': 1})
# E-GEOD-14671, Counter({'chronic myeloid leukaemia': 1})
# Counter({'  ': 1})
# E-GEOD-15065, Counter({'breast fibrocystic disease': 1})
# Counter({'breast': 1})
# E-GEOD-16547, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-17440, Counter({'HIV': 1})
# Counter({'frontal cortex': 1})
# E-GEOD-18239, Counter({'T-ALL': 1})
# Counter({'  ': 1})
# E-GEOD-19686, Counter({'glioma': 1})
# Counter({'brain': 1})
# E-GEOD-20300, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-20504, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-22106, Counter({'normal': 1})
# Counter({'fetal intestine': 1})
# E-GEOD-22572, Counter({'colon adenocarcinoma': 1})
# Counter({'colon': 1})
# E-GEOD-2328, Counter({'normal': 1})
# Counter({'skeletal muscle': 1})
# E-GEOD-4984, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-6090, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-6565, Counter({'normal': 1})
# Counter({'fetal cartilage': 1})
# E-GEOD-7047, Counter({'cervical adenocarcinoma': 1})
# Counter({'cervix': 1})
# E-GEOD-7234, Counter({'normal': 1})
# Counter({'  ': 1})
# GSM187763.CEL, Counter({'c-ALL': 1})
# Counter({'bone marrow': 1})
# GSM187790.CEL, Counter({'c-ALL': 1})
# Counter({'bone marrow': 1})
# E-MEXP-2582, Counter({'liver mesenchymal tumor': 1})
# Counter({'liver': 1})
# E-MTAB-203, Counter({'normal': 1})
# Counter({'pancreatic islet': 1})
# FFR2006022704Aaa.cel, Counter({'normal': 1})
# Counter({'blood': 1})
# E-GEOD-10537, Counter({'diffuse histiocytic lymphoma': 1})
# Counter({'pleura': 1})
# E-GEOD-11057, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-11309, Counter({'autoimmune polyendocrinopathy-candidiasis-ectodermal dystrophy': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-15209, Counter({'normal': 1})
# Counter({'fetal cortex': 1})
# E-GEOD-17714, Counter({'neuroblastoma': 1})
# Counter({'brain': 1})
# E-GEOD-18557, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-4250, Counter({'hereditary gingival fibromatosis': 1})
# Counter({'gingiva': 1})
# E-GEOD-6400, Counter({'lung adenocarcinoma': 1})
# Counter({'lung': 1})
# E-GEOD-7462, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-7510, Counter({'graft-versus-host disease': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-9526, Counter({'normal': 1})
# Counter({'  ': 1})
# E-MEXP-2128, Counter({'normal': 1})
# Counter({'liver': 1})
# E-GEOD-11285, Counter({'glioblastoma': 1})
# Counter({'brain': 1})
# E-GEOD-10196, Counter({'breast fibrocystic disease': 1})
# Counter({'breast': 1})
# E-GEOD-11504, Counter({'normal': 1})
# Counter({'bone marrow': 1})
# E-GEOD-14000, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-14474, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-15520, Counter({'hepatoma': 1})
# Counter({'liver': 1})
# E-GEOD-16452, Counter({'neuroblastoma': 1})
# Counter({'brain': 1})
# E-GEOD-20433, Counter({'prostate adenocarcinoma': 1})
# Counter({'prostate': 1})
# E-GEOD-26471, Counter({'cervical adenocarcinoma': 1})
# Counter({'cervix': 1})
# E-GEOD-27318, Counter({'nasopharingeal carcinoma': 1})
# Counter({'  ': 1})
# E-GEOD-5486, Counter({'colon adenocarcinoma': 1})
# Counter({'colon': 1})
# E-GEOD-7440, Counter({'high risk B-precurser ALL': 1})
# Counter({'bone marrow': 1})
# E-GEOD-7807, Counter({'normal': 1})
# Counter({'  ': 1})
# 6_NP.CEL, Counter({'Thompson disease': 1})
# Counter({'Intervertebral disc': 1})
# E-MEXP-875, Counter({'lung adenocarcinoma': 1})
# Counter({'lung': 1})
# E-GEOD-12287, Counter({'ATL': 1})
# Counter({'blood': 1})
# E-GEOD-12606, Counter({'renal cell carcinoma': 1})
# Counter({'kidney': 1})
# E-GEOD-13477, Counter({'breast adenocarcinoma': 1})
# Counter({'breast': 1})
# E-GEOD-15151, Counter({'myelodysplasia': 1})
# Counter({'blood': 1})
# E-GEOD-16683, Counter({'normal': 1})
# Counter({'umbilical vein': 1})
# E-GEOD-19136, Counter({'angina/coronary atherosclerosis': 1})
# Counter({'LIMA artery': 1})
# E-GEOD-8717, Counter({'malignant peripheral nerve sheath tumor': 1})
# Counter({'peripheral nerve sheath': 1})
# E-GEOD-9055, Counter({'normal': 1})
# Counter({'umbilical vein': 1})
# E-MEXP-1425, Counter({'obesity': 1})
# Counter({'  ': 1})
# E-MEXP-1482, Counter({'chronic myelogenous leukaemia': 1})
# Counter({'bone marrow': 1})
# E-MEXP-1900, Counter({'hydrolethalus syndrome': 1})
# Counter({'skin': 1})
# E-MEXP-2065, Counter({'breast ductal carcinoma': 1})
# Counter({'breast': 1})
# E-MEXP-2143, Counter({'normal': 1})
# Counter({'skin': 1})
# E-MEXP-563, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-11854, Counter({'normal': 1})
# Counter({'skin': 1})
# E-GEOD-18912, Counter({'breast adenocarcinoma': 1})
# Counter({'breast': 1})
# E-GEOD-9103, Counter({'normal': 1})
# Counter({'vastus lateralis': 1})
# E-GEOD-10334, Counter({'diseased (bleeding on probing)': 1})
# Counter({'gingiva': 1})
# E-GEOD-10718, Counter({'normal': 1})
# Counter({'bronchus': 1})
# E-GEOD-10820, Counter({'ALL': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-12086, Counter({'recessive retinitis pigmentosa': 1})
# Counter({'  ': 1})
# E-GEOD-13785, Counter({'asthma': 1})
# Counter({'sputum': 1})
# E-GEOD-15237, Counter({'eosinophilic leukaemia': 1})
# Counter({'blood': 1})
# E-GEOD-15659, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-16715, Counter({'normal': 1})
# Counter({'skin': 1})
# E-GEOD-22166, Counter({'normal': 1})
# Counter({'umbilical vein': 1})
# E-GEOD-4600, Counter({'neuroblastoma': 1})
# Counter({'brain': 1})
# E-GEOD-6257, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-8784, Counter({'cervical adenocarcinoma': 1})
# Counter({'cervix': 1})
# E-GEOD-9234, Counter({'colorectal adenocarcinoma': 1})
# Counter({'colon': 1})
# E-GEOD-9361, Counter({'normal': 1})
# Counter({'kidney': 1})
# E-GEOD-9764, Counter({'normal': 1})
# Counter({'bone marrow': 1})
# E-MEXP-1857, Counter({'small cell lung cancer': 1})
# Counter({'lung': 1})
# E-MEXP-390, Counter({'colon carcinoma': 1})
# Counter({'colon': 1})
# E-GEOD-6890, Counter({'cervical adenocarcinoma': 1})
# Counter({'cervix': 1})
# E-MEXP-2083, Counter({"active Crohn's disease": 1})
# Counter({'colon': 1})
# E-GEOD-10879, Counter({'breast adenocarcinoma': 1})
# Counter({'breast': 1})
# E-GEOD-11919, Counter({'normal': 1})
# Counter({'skin': 1})
# E-GEOD-14841, Counter({'diarrhea-irritable bowel syndrome': 1})
# Counter({'jejunal mucosa': 1})
# GSM386028.CEL, Counter({'colorectal cancer': 1})
# Counter({'colon': 1})
# E-GEOD-15455, Counter({'gastric adenocarcinoma': 1})
# Counter({'stomach': 1})
# E-GEOD-15553, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-15645, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-17539, Counter({'normal': 1})
# Counter({'cultured skin substitute': 1})
# E-GEOD-18144, Counter({'neuroblastoma': 1})
# Counter({'brain': 1})
# E-GEOD-21066, Counter({'breast fibrocystic disease': 1})
# Counter({'breast': 1})
# E-GEOD-21760, Counter({'cervical adenocarcinoma': 1})
# Counter({'cervix': 1})
# E-GEOD-26455, Counter({'normal': 1})
# Counter({'  ': 1})
# GSM187735.CEL, Counter({'c-ALL': 1})
# Counter({'bone marrow': 1})
# E-MEXP-2167, Counter({'normal': 1})
# Counter({'prostate': 1})
# E-MEXP-2172, Counter({'metastatic prostate cancer': 1})
# Counter({'prostate': 1})
# E-MTAB-362, Counter({'multiple myeloma': 1})
# Counter({'bone marrow': 1})
# E-GEOD-12548, Counter({'normal': 1})
# Counter({'retina': 1})
# E-GEOD-13975, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-14017, Counter({'breast cancer': 1})
# Counter({'  ': 1})
# E-GEOD-15658, Counter({'osteosarcoma': 1})
# Counter({'bone': 1})
# E-GEOD-15811, Counter({'normal': 1})
# Counter({'umbilical cord blood': 1})
# E-GEOD-17032, Counter({'normal': 1})
# Counter({'skin': 1})
# E-GEOD-17386, Counter({'hepatocellular carcinoma': 1})
# Counter({'liver': 1})
# E-GEOD-19197, Counter({"Ewing's sarcoma": 1})
# Counter({'brain': 1})
# E-GEOD-19445, Counter({'prostate adenocarcinoma': 1})
# Counter({'prostate': 1})
# E-GEOD-19982, Counter({'renal oncocytoma': 1})
# Counter({'kidney': 1})
# E-GEOD-21774, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-23994, Counter({'normal': 1})
# Counter({'breast': 1})
# E-GEOD-6357, Counter({'normal': 1})
# Counter({'  ': 1})
# E-MEXP-2559, Counter({'normal': 1})
# Counter({'skeletal muscle': 1})
# E-MEXP-993, Counter({'prostate adenocarcinoma': 1})
# Counter({'prostate': 1})
# E-GEOD-6798, Counter({'polycystic ovary syndrome': 1})
# Counter({'vastus lateralis': 1})
# E-GEOD-10799, Counter({'normal': 1})
# Counter({'lung': 1})
# E-GEOD-11118, Counter({'T-cell leukaemia': 1})
# Counter({'blood': 1})
# E-GEOD-11279, Counter({'colon adenocarcinoma': 1})
# Counter({'colon': 1})
# E-GEOD-11440, Counter({'colorectal adenocarcinoma': 1})
# Counter({'colon': 1})
# E-GEOD-16098, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-16755, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-17307, Counter({'lung adenocarcinoma': 1})
# Counter({'lung': 1})
# E-GEOD-17540, Counter({'breast adenocarcinoma': 1})
# Counter({'breast': 1})
# E-GEOD-19060, Counter({'osteoarthritis': 1})
# Counter({'  ': 1})
# E-GEOD-19703, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-22109, Counter({'normal': 1})
# Counter({'  ': 1})
# E-GEOD-27128, Counter({'lung adenocarcinoma': 1})
# Counter({'lung': 1})
# E-GEOD-6351, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-GEOD-6863, Counter({'normal': 1})
# Counter({'peripheral blood': 1})
# E-MEXP-1601, Counter({'normal': 1})
# Counter({'blood': 1})
# E-MEXP-2276, Counter({'normal': 1})
# Counter({'fetal cartilage': 1})
# E-MEXP-2556, Counter({'osteosarcoma': 1})
# Counter({'bone': 1})
# 4_NP.CEL, Counter({'Thompson disease': 1})
# Counter({'Intervertebral disc': 1})

# %% [markdown]
# The second selected disease will be acute myeloid leukaemia since there is a groupd of very good candidate in the test data set with reasonable numbers and good experimental design (bone marrow, normal versus disease). We can also add one more group to compare between breast adenocarcinoma and lung adenocarcinoma -- E-GEOD-15061
